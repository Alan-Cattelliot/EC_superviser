# %%
import pandas as pd
import plotly.express as px
from IPython.display import display, Math, HTML, Image
import plotly.graph_objects as go
import numpy as np
import xml.etree.ElementTree as ET

# %%
from datetime import datetime
from time import gmtime, strftime


def taketime():
    time = datetime.today()
    time = time.replace(microsecond = 0).isoformat() 
    utc_time = datetime.utcnow()
    utc_time = utc_time.replace(microsecond = 0).isoformat() 
    
    return time,utc_time

# %%
#email infra
import os

from email.mime.base import MIMEBase
from email.mime.text import MIMEText
from email import encoders

# Html
import smtplib
from email.utils import formatdate
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import re
regex = r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
import mimetypes
from pathlib import Path

# %%
path = "./DB_12215/"
#read core properties database
file = "Proprietes_ames_recover.csv"
# Make a regular expression
# for validating an Email
table = pd.read_csv(path + file)

# %%
#read csv
file = "Tableau 2.csv"
procedure_generale = pd.read_csv(path + file,delimiter=",")

# %%
uploaded_filename =""

# %%
import ipywidgets as widgets
from ipywidgets import Layout, Button, VBox, Label, HBox , FileUpload

buttonlayout = Layout(overflow_x='hidden',
                    overflow_y='auto',
                      #width='500px',
                    height='58px',
                    #flex_flow='
                    display='flex',
                    align_items='stretch',
                    justify_content = 'center',
                    flex_flow='column',
                    width='98%',
                    )
form_layout = Layout(
                    #overflow_x='hidden',
                    #overflow_y='auto',
                    height='520px',
                    display='flex',
                    align_items='stretch',
                    #border='1px solid black', 
                    justify_content = 'flex-start',
                    flex_flow='column',
                    #border='solid',
                    width='98%'
)
form_layout640 = Layout(
                    #overflow_x='hidden',
                    #overflow_y='auto',
                    height='600px',
                    display='flex',
                    align_items='stretch',
                    #border='1px solid black', 
                    justify_content = 'flex-start',
                    flex_flow='column',
                    #border='solid',
                    width='100%'
)
form_layoutboxed = Layout(
                    #overflow_x='hidden',
                    #overflow_y='auto',
                    height='480px',
                    display='flex',
                    align_items='stretch',
                    #border='1px solid black', 
                    justify_content = 'flex-start',
                    flex_flow='column',
                    #border='solid',
                    width='100%'
)
form_layoutboxedsmall = Layout(
                    #overflow_x='hidden',
                    #overflow_y='auto',
                    height='340px',
                    display='flex',
                    align_items='stretch',
                    #border='1px solid black', 
                    justify_content = 'flex-start',
                    flex_flow='column',
                    #border='solid',
                    width='100%'
)
general_layout = Layout(
                    #overflow_x='hidden',
                    #overflow_y='auto',
                    #height='1000px',
                    #display='flex',
                    align_items='stretch',
                    border='1px solid black', 
                    justify_content = 'center',
                    flex_flow='line',
                    #border='solid',
                    width='100%'
)
form_layout620 = Layout(
                    #overflow_x='hidden',
                    #overflow_y='auto',
                    height='250px',
                    display='flex',
                    align_items='stretch',
                    border='1px solid black', 
                    justify_content = 'flex-start',
                    flex_flow='column',
                    #border='solid',
                    #width='100%'
)

head_display_layout = Layout(overflow_x='hidden',
                    overflow_y='auto',
                    #flex_flow='line',
                    height='120px',
                    display='flex',
                    #border='1px solid black', 
                    align_items='flex-end',
                    justify_content = 'space-between',
                    flex_flow='line',
                    #border='solid',
                    width='100%')
head_display2_layout = Layout(overflow_x='hidden',
                    overflow_y='auto',
                    #flex_flow='line',
                    height='120px',
                    display='flex',
                    #border='1px solid black', 
                    align_items='flex-start',
                    justify_content = 'space-between',
                    flex_flow='line',
                    #border='solid',
                    width='100%')

center_layout = Layout(
                    display='flex',
                    align_items='stretch',
                    justify_content = 'center',
                    flex_flow='line',
                    #border='solid',
                    width='100%')

upper_layout = Layout(
                    display='flex',
                    align_items='stretch',
                    justify_content = 'center',
                    flex_flow='line',
                    #border='solid',
                    width='100%')

lower_layout = Layout(
                    display='flex',
                    align_items='stretch',
                    justify_content = 'center',
                    flex_flow='line',
                    #border='solid',
                    width='100%')

# %%
# upload submitter files

# create callback function for uploader            
def response(change):
    
    global root 
    global uploaded_filename
    
    #Upload content    
    uploaded_filename = next(iter(uploader.value))
    content = uploader.value[uploaded_filename]['content']
    with open(uploaded_filename, 'wb') as f: f.write(content)
    
    #Read structure
    tree = ET.parse(uploaded_filename)
    root = tree.getroot()
    
    search = [elem.tag == 'mLDC' for elem in root]
    searchIndex = [i for i, x in enumerate(search) if x]
    mldcButton.value = root[searchIndex[0]].text
    
    search = [elem.tag == 'LWL' for elem in root]
    searchIndex = [i for i, x in enumerate(search) if x]
    lwlButton.value = root[searchIndex[0]].text
    
    search = [elem.tag == 'Constructeur' for elem in root]
    searchIndex = [i for i, x in enumerate(search) if x]
    if len(searchIndex)==0:
         search = [elem.tag == 'constructeur' for elem in root]
         searchIndex = [i for i, x in enumerate(search) if x]
    elif len(searchIndex)==0:
        submitterNameButton.value = ''
    
    submitterNameButton.value = root[searchIndex[0]].text

        
    search = [elem.tag == 'Reference' for elem in root]
    searchIndex = [i for i, x in enumerate(search) if x]
    if len(searchIndex)==0:
        search = [elem.tag == 'reference' for elem in root]
        searchIndex = [i for i, x in enumerate(search) if x]
    elif len(searchIndex)==0:
        modeleButton.value = ''

    modeleButton.value = root[searchIndex[0]].text
        
    search = [elem.tag == 'Architecte' for elem in root]
    searchIndex = [i for i, x in enumerate(search) if x]
    if len(searchIndex)==0:
        search = [elem.tag == 'architecte' for elem in root]
        searchIndex = [i for i, x in enumerate(search) if x]
    elif len(searchIndex)==0:
        architecteButton.value = ''
    name = root[searchIndex[0]].text
    architecteButton.value = name.capitalize()

    time,utc_time = taketime()
    
    update_TechnicalDocumentation(True)
    
    #"LOCAL:" + time +"   UTC:" + utc_time
    

uploadlayout = Layout(overflow_x='hidden',
                overflow_y='auto',
                  #width='500px',
                height='28px',
                #flex_flow='
                #display='flex',
                align_items='stretch',
                align_content = 'stretch',
                justify_content = 'flex-start',
                flex_flow='column',
                )   
    
uploader = FileUpload(
    multiple=False,
    accept='*.iscn',
    description='',
    layout=uploadlayout,
)
uploader.observe(response, names='value')

# %%
Title46 = ""
Title46 = Title46 \
+ "<font size=1> file name</font><br><font size=2><b><u>" \
+ "bob" \
+ "</u></b><br></font>"

# %%
def update_control(change):
    global listeControls
    
    
    Title42.value = "<font size=1> code</font><br><font size=2><b><u>" \
    + listeControls[listeControls['Nom'] == controlButton.value].Code.tolist()[0] \
    + "</u></b><br></font>"


    Title43.value = "<font size=1> requirements to be assessed</font></font><br><font size=2><b><u>" \
        + listeControls[listeControls['Nom'] == controlButton.value].Requirement.tolist()[0] \
        + "</u></b><br></font"

    Title44.value ="<font size=1> standard reference</font></b></font><br><font size=2><b><u>" \
        + listeControls[listeControls['Nom'] == controlButton.value].Reference.tolist()[0] \
        + "</u></b></font>"

    Title455.value ="<font size=1> subject</font></b></font><br><font size=2><b><u>" \
        + controlButton.value \
        + "</u></b></font>"

    Title45.value ="<font size=1> importance</font></b></font><br><font size=2><b><u>" \
        + listeControls[listeControls['Nom'] == controlButton.value].Importance.tolist()[0] \
        + "</u></b></font>"

    
def update_TechnicalDocumentation(change):
    
    global table
    global uploaded_filename
    
    Title46.value = "<font size=1> file name</font><br><font size=2><b><u>" \
    + table[table["Reference"] == matiereButton.value].Nom.tolist()[0] \
    + "</u></b><br></font>"

    Title47.value = "<font size=1> form type</font><br><font size=2><b><u>" \
        + table[table["Reference"] == matiereButton.value].Form.tolist()[0] \
        + "</u></b><br></font>"

    Title48.value = "<font size=1> form date</font><br><font size=2><b><u>" \
        + table[table["Reference"] == matiereButton.value].Date.tolist()[0] \
        + "</u></b><br></font>"

    Title49.value = "<font size=1> form source</font><br><font size=2><b><u> \
        SUPPLIER \
        </u></b><br></font>"
    Title50.value = "<font size=1> status</font><br><font size=2><b><u> \
         THRUSTED\
        </u></b><br></font>"
    Title500.value = "<font size=3> TECHNICAL DOCUMENTATION</font>"
    Title501.value = "<font size=1> category</font><br><font size=2><b><u> \
     material\
    </u></b><br></font>" 
    
    if uploaded_filename != "":
        Title46.value = Title46.value \
        + "<font size=2><b><u>" \
        + uploaded_filename \
        + "</u></b><br></font>"

        Title47.value = Title47.value \
        + "<font size=2><b><u>" \
        + "ISCANT-xml" \
        + "</u></b><br></font>"

        Title48.value = Title48.value \
        + "<font size=2><b><u>" \
        + datetime.today().strftime('%d/%m/%Y') \
        + "</u></b><br></font>"

        Title49.value = Title49.value \
        + "<font size=2><b><u>" \
        + "SUBMITTER \
        </u></b><br></font>"

        Title50.value = Title50.value \
        + "<font size=2><b><u>" \
        + "\
        SELF-DECLARED\
        </u></b><br></font>"

        Title501.value =  Title501.value \
        + "<font size=2><b><u>" \
        + "\
        calculations \
        </u></b><br></font>"
    
    
def update_contract(change):
    change_language(True)

# %%
def sendEmail(sujet,html,pieces):
    
    
    
    server = smtplib.SMTP_SSL('diego.o2switch.net') # On utilise SMTP_SSL() à la place de SMTP()
    # server.set_debuglevel(1) # Décommenter pour activer le debug
    server.connect('diego.o2switch.net')
    # (220, 'toto ESMTP Postfix') # Réponse du serveur
    server.ehlo() # ATTENTION, avec SSL, c'est la commande EHLO au lieu de HELO
    #(250, 'toto\nPIPELINING\nSIZE 10240000\nVRFY\nETRN\nAUTH LOGIN PLAIN\nAUTH=LOGIN PLAIN\nENHANCEDSTATUSCODES\n8BITMIME\nDSN') # Réponse du serveur
    serverOutput.value = 'Connected to diego.o2switch.net'
    hipo = 'dpoubduAbdf.obvujd/gs'
    opih = 'z2^kP*Jyjv/6'
    
    sliced = [char for char in hipo]
    a = [ord(i) for i in sliced]
    b = [i-1 for i in a]
    c = [chr(i) for i in b]
    d = ''.join(c)
    sliced = [char for char in opih]
    a = [ord(i) for i in sliced]
    b = [i-1 for i in a]
    c = [chr(i) for i in b]
    e = ''.join(c)        
       
    lipopo = d
    lopipi = e
    server.login(lipopo, lopipi) # On s'authentifie
    # (235, '2.7.0 Authentication successful') # Réponse du serveur
    fromaddr = '<contact@ace-nautic.fr>'
    toaddrs = ['alan.cattelliot@gmail.com'] # On peut mettre autant d'adresses que l'on souhaite
    #sujet = "EN-ISO12215-5:2019 A.7 Révision de la conformité pour les âmes. Conformity revision for core materials"
    text = """\
    -Le contenu de ce message est généré par un bot. The content of the message is generated by a bot.-
    -Prière d'utiliser cette adresse email pour toute demande. Please use this email address for any request.-
    """
    msg = MIMEMultipart('alternative')
    msg.add_header('Content-Type','text/html')
    msg['Subject'] = sujet
    msg['From'] = fromaddr
    #msg['To'] = ','.join(toaddrs)
    msg['To'] = emailForm.value
    msg["Date"] = formatdate(localtime=True)

    part1 = MIMEText(text, "plain")
    part2 = MIMEText(html, 'html')
    msg.attach(part1)
    msg.attach(part2)
    
    # attaching files files = ['test.pdf']
    if pieces != '':
        serverOutput.value = 'Adding attachments...'
        for path in pieces:
            part = MIMEBase('application', "octet-stream")
            with open(path, 'rb') as file:
                part.set_payload(file.read())
            encoders.encode_base64(part)
            part.add_header('Content-Disposition',
                            'attachment; filename={}'.format(Path(path).name))
            msg.attach(part)
        serverOutput.value = 'Attachment successfully added.'
    
    
    try:
        serverOutput.value = 'Sending message...'
        server.sendmail(fromaddr, toaddrs, msg.as_string())
    except smtplib.SMTPException as e:
        serverOutput.value = e
    # {} # Réponse du serveur
    server.quit()
    serverOutput.value = 'Message send successfully.'
    # (221, '2.0.0 Bye')

# %%
def checkEmail(email):
 
    # pass the regular expression
    # and the string into the fullmatch() method
    if(re.fullmatch(regex, email)):
        return True
 
    else:
        return False

# %%
mldc=np.linspace(1,70000,50)
t=np.linspace(0,24,50)


#read csv
file = "listeDesignCategory.csv"
listeDesignCategory = pd.read_csv(path + file,delimiter=",")
file = "listeControls.csv"
listeControls = pd.read_csv(path + file,delimiter=";")
file = "listeContext.csv"
listeContext = pd.read_csv(path + file,delimiter=";")

# %%
# Create design category button
listeDesignCategoryButton = widgets.Dropdown(
    options=listeDesignCategory['Design category'],
    description ='Design category',
    disabled=False,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    style= {'description_width': 'initial'},
    #tooltips='',
    layout=buttonlayout,
#      icons=['check'] * 3
)        

controlButton  = widgets.Dropdown(
    options=listeControls['Nom'],
    description='choose procedure',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout=buttonlayout,
    style= {'description_width': 'initial'}
)

submitterTypeButton  = widgets.Dropdown(
    options=['Designer&Engineer','Manufacturer','Institutionnal','User'],
    description='',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    #layout=buttonlayout,
    #style= {'description_width': 'initial'}
)

contextButton  = widgets.Dropdown(
    options=listeContext['Nom'] + " - "+ listeContext['Type'],
    description="context",
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout=buttonlayout,
    style= {'description_width': 'initial'}
)


modeleTypeButton  = widgets.Dropdown(
    options=["Moteur à déplacement", "Moteur planant", "Voilier"],
    description="",
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    #layout=buttonlayout,
    #style= {'description_width': 'initial'}
)



languageButton = widgets.RadioButtons(
    options=['français','english','deutsch','italiano','español'],
    description='select language',
    disabled=False,
    orientation='horizontal',
    continuous_update=False,
    #layout = buttonlayout,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=procedure_generale.loc[6:11,'Article N°'].tolist(),
    style= {'description_width': 'initial'}
#     icons=['check'] * 3
)  

methodeButton = widgets.ToggleButtons(
    options=procedure_generale.loc[6:11,'Sujet'].tolist(),
    description="",
    disabled=False,
    continuous_update=False,
    layout = buttonlayout,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=procedure_generale.loc[6:11,'Article N°'].tolist(),
    style= {'description_width': 'initial'}
#     icons=['check'] * 3
)

lwlButton  = widgets.BoundedFloatText(
    value=10,
    min=0,
    max=24,
    step=0.01,
    description='lwl in meters',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.3f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)


mldcButton  = widgets.BoundedFloatText(
    value=3000,
    min=1,
    max=70000,
    step=10,
    description='mldc in kilogram',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)

matiereButton = widgets.Dropdown(
    options=table["Reference"].tolist(),
    description="subject",
    disabled=False,
    continuous_update=False,
    layout = buttonlayout,
    button_style='', # 'success', 'info', 'warning', 'danger' or ''
    tooltips=table["Matiere"].tolist(),
    style= {'description_width': 'initial'}
#     icons=['check'] * 3
)

architecteButton  = widgets.Text(
    value='',
    description='Architecte',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)


submitterFirstNameButton = widgets.Text(
    value='',
    description='Prénom',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)


submitterNameButton  = widgets.Text(
    value='',
    description='Nom',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)

submitterAdress  = widgets.Text(
    value='',
    description='Adresse',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)
    
submitterTown  = widgets.Text(
    value='',
    description='Ville',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)
    
submitterPost  = widgets.Text(
    value='',
    description='Code postal',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)
    
submitterCountry  = widgets.Text(
    value='',
    description='Pays',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)

modeleButton  = widgets.Text(
    value='',
    description='Modèle',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)

constructeurButton = widgets.Text(
    value='',
    description='Constructeur',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)

uniteButton = widgets.Text(
    value='',
    description='Nom du bateau',
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)

WINBUTTON = widgets.Text(
    value='',
    description="Numéro d'identification de coque",
    disabled=False,
    continuous_update=True,
    orientation='horizontal',
    readout=True,
    readout_format='.0f',
    layout = buttonlayout,
    style= {'description_width': 'initial'}
)



emailForm = widgets.Text(
        value='@',
        placeholder='@',
        description="Email(*)",
        disabled=False,
        continuous_update=True,
        orientation='horizontal',
        readout=True,
        readout_format='.0f',
        layout = buttonlayout,
        style= {'description_width': 'initial'}
    
)
sendemailButton = widgets.Button(
        description='Send',
        disabled=False,
        button_style='', # 'success', 'info', 'warning', 'danger' or ''
        tooltip='',
        icon='fa-paper-plane',
)

serverOutput = widgets.HTML(
    value="Server offline",
    placeholder='',
    description='',
)

submitname3 = widgets.HTML(
    value="",
    placeholder='',
    description='',
)

submitname3.value = "<font size=2>The SUBMITTER </font><font size=2><b><u>"\
+ submitterNameButton.value\
+ "</u></b></font>\
<font size=2> calls upon the CONTROL AUTHORITY </font><font size=2><b><u> \
A.C.E CATTELLIOT ENGINEERING\
</u></b></font>\
<font size=2> to evaluate the designated core material </font><font size=2><b><u>"\
+ matiereButton.value \
+ "</u></b></font>\
<font size=2> regarding the compliancy of the PRODUCT </font><font size=2><b><u>"\
+ modeleButton.value \
+ "</u></b></font>\
<font size=2> with the REGULATION </font><font size=2><b><u>"\
+ contextButton.value \
+ "</u></b></font><font size=2> following the PROCEDURE of evaluation </font><font size=2><b><u>" \
+ controlButton.value \
+ "</u></b></font>." 


confirmSubmitterButton = widgets.Button(
        description='Submit',
        disabled=True,
        button_style='info', # 'success', 'info', 'warning', 'danger' or ''
        tooltip='',
        icon='check-circle',
)

confirmProductButton = widgets.Button(
        description='Submit',
        disabled=True,
        button_style='info', # 'success', 'info', 'warning', 'danger' or ''
        tooltip='',
        icon='check-circle',
)

confirmContractButton = widgets.Button(
        description='Submit',
        disabled=True,
        button_style='info', # 'success', 'info', 'warning', 'danger' or ''
        tooltip='',
        icon='check-circle',
)


def check_Contract(change):
    global nocontractIcone
    if (confirmSubmitterButton.description == "Identified")\
    and (confirmProductButton.description == "Identified")\
    and Title455.value !="<font size=1>subject</font>"\
    and Title46.value != "<font size=1>file name</font>":
        confirmContractButton.disabled = False
        confirmContractButton.button_style='warning'
        confirmContractButton.description ='Confirm'
        details.value = ""
        g.value =""
        f.value =""
        contractZone.value = nocontractIcone
    if confirmContractButton.description =='Accepted':
        confirmContractButton.disabled = False
        confirmContractButton.button_style='warning'
        confirmContractButton.description ='Confirm'
        contractZone.value = nocontractIcone
        details.value = ""
        g.value =""
        f.value =""
        
def check_Submitter(change):
    global nocontractIcone
    check = checkEmail(emailForm.value)
    if (submitterNameButton.value != "")\
    and (submitterAdress.value != "")\
    and (submitterTown.value != "")\
    and (submitterPost.value != "")\
    and (submitterCountry.value != "")\
    and (check == True)\
    and (confirmSubmitterButton.button_style == 'info'):
        confirmSubmitterButton.disabled = False
        confirmSubmitterButton.button_style='warning'
        confirmSubmitterButton.description ='Confirm'
    elif confirmSubmitterButton.button_style == 'success':
        confirmSubmitterButton.disabled = False
        confirmSubmitterButton.button_style='warning'
        confirmSubmitterButton.description ='Confirm'
        details.value = ""
        g.value =""
        f.value =""
    if confirmSubmitterButton.description =='Confirm':
        contractZone.value = nocontractIcone
        confirmContractButton.disabled = True
        confirmContractButton.button_style='warning'
        confirmContractButton.description ='Confirm'
        details.value = ""
        g.value =""
        f.value =""
        
        
def check_Product(change):
    global nocontractIcone
    if ((uniteButton.value != "")or(WINBUTTON.value != ""))\
    and (mldcButton.value != "")\
    and (lwlButton.value != "")\
    and (listeDesignCategoryButton.value != ""):
        confirmProductButton.disabled = False
        confirmProductButton.button_style='warning'
        confirmProductButton.description ='Confirm'
    elif confirmProductButton.button_style == 'success':
        confirmProductButton.disabled = False
        confirmProductButton.button_style='warning'
        confirmProductButton.description ='Confirm'
        details.value = ""
        g.value =""
        f.value =""
    if confirmProductButton.description =='Confirm':
        contractZone.value = nocontractIcone
        confirmContractButton.disabled = True
        confirmContractButton.button_style='warning'
        confirmContractButton.description ='Confirm'
        details.value = ""
        g.value =""
        f.value =""

        
def confirm_Submitter(change):
    confirmSubmitterButton.button_style='success'
    confirmSubmitterButton.description ='Identified'
    confirmSubmitterButton.disabled = True
    check_Contract(True)
    
    time,utc_time = taketime()
    
    if languageButton.value == 'english':
        sujet = "Registration as an applicant on the ISO12215:2019 application platform" 
        html = "Hello,<br><br>Thank you for using our services. You can now file one or more control requests.<br>\
        Keep the data that we send to you in a safe place. This data should be presented\
        so that we can study any request relating to the data provided at the end of the control.\
        <br>Finally, we remind you that the controller you are using is a created automaton\
        at your request, by A.C.E. CATTELLIOT ENGINEERING and of which we grant you a limited access.\
        .<br><br><b><u>This automaton is personal to you (virtual computer inaccessible from the outside).\
        when it is deleted, the form data, the exchanged data as well as the storage data are deleted.</u></b>\
        For internal control purposes, a copy of this letter is sent to our company.<br><br>\
        We wish you good use of our services. If you have any questions, please do not hesitate\
        to contact us. Our young company is dedicated to creating\
        the practical link between all the players in yachting, and we are always keen to know your\
        specific issues.\
        <br><br>\
        Best regards,\
        <br><br><br><br><br>\
        <code>A.C.E. CATTELLIOT ENGINEERING is a service company for yachting and offshore racing, affiliated to the Federation of Nautical Industries,\
        approved by contract with the notified body ENAVE for the European Directive for Recreationnal boats, in the sectors <b>Recreational boating, Offshore Racing, National Regulations (DIV245)</b>.<br>\
        Please use this email address for all inquiries.</code>" 
        
    elif languageButton.value == 'français':
        sujet = "Enregistrement en tant que demandeur sur la plate forme d'application ISO12215:2019"
        html = "Bonjour,<br><br>Merci de solliciter nos services. Vous pouvez maintenant déposer une ou plusieurs demandes de contrôle.<br>\
        Conservez précieusement les données que nous vous transmettrons. Ces données devront être présentées\
        afin que nous puissions étudier toute demande relative aux données issues de ce contrôle.\
        <br>Nous vous rappelons enfin que le contrôleur que vous utilisez est un automate créé\
        à votre demande, par A.C.E. CATTELLIOT ENGINEERING et dont nous vous concédons\
        une utilisation limitée. <br><br> <b><u>Cet automate vous est personnel (ordinateur virtuel inaccessible ad-hoc).\
        lors de sa suppression, les données de formulaires, les données échangées ainsi que les données de stockage sont supprimées.</u></b>\
        A fin de contrôle interne, une copie de ce courrier nous est adressée.<br><br>\
        Nous vous souhaitons une bonne utilisation de nos services. Pour toute question, \
        contactez nous. Notre jeune société se voue à créer\
        le lien pratique entre tous les acteurs de la plaisance, et nous avons toujours à coeur de connaitre vos\
        problématiques particulières.\
        <br><br>Bien cordialement,\
        <br><br><br><br><br><br>\
        <code>A.C.E. CATTELLIOT ENGINEERING est une société de service pour la Plaisance et la Course au Large, affiliée à la Fédération des Industries Nautiques,\
        agréée par contrat par ENAVE, organisme notifié pour la Directive Européenne de Plaisance, dans les secteurs <b>Plaisance, Course au large, Réglementation Nationale(DIV245)</b>.<br>\
        Prière d'utiliser cette adresse mail pour toute demande.</code>"
              
    elif languageButton.value == "deutsch":
        sujet = "Registrierung als Bewerber auf der Bewerbungsplattform ISO12215:2019" 
        html = "Hallo,<br><br>Danke, dass Sie unsere Dienste nutzen. Sie können jetzt eine oder mehrere Kontrollanfragen stellen.<br>\
        Bewahren Sie die Daten, die wir Ihnen zusenden, an einem sicheren Ort auf. Diese Daten sollten präsentiert werden\
        damit wir jede Anfrage in Bezug auf die am Ende der Kontrolle bereitgestellten Daten prüfen können.\
        <br>Abschließend möchten wir Sie daran erinnern, dass der von Ihnen verwendete Controller ein erstellter Automat ist\
        auf Ihren Wunsch von A.C.E. CATTELIOT ENGINEERING und davon gewähren wir Ihnen\
        eine beschränkte Verwendung. <br><br><b><u>Dieser Automat ist für Sie persönlich (virtueller Computer, der von außen nicht zugänglich ist).\
        beim Löschen werden Formulardaten, ausgetauschte Daten und Speicherdaten gelöscht.</u></b>\
        Zu internen Kontrollzwecken wird uns eine Kopie dieses Schreibens zugesandt.<br><br>\
        Wir wünschen Ihnen eine gute Nutzung unserer Dienste. Wenn Sie Fragen haben, zögern Sie bitte nicht\
        um uns zu kontaktieren. Unser junges Unternehmen widmet sich der Erstellung\
        die praktische Verbindung zwischen allen Akteuren im Segelsport, und wir sind immer daran interessiert, Ihre\
        spezifische Fragen.\
        <br><br>\
        Mit freundlichen Grüßen,\
        <br><br><br><br>\
        <code>A.C.E. CATTELLIOT ENGINEERING ist ein Serviceunternehmen für Segel- und Hochseeregatten, das der Federation of Nautical Industries angeschlossen ist,\
        zugelassen durch Vertrag mit der benannten Stelle ENAVE für die Europäische Dienstleistungsrichtlinie der nichtgewerbliche Schifffahrt, in den Sektoren <b> Private nichtgewerbliche Schifffahrt, Offshore Racing</b>.<br>\
        Bitte verwenden Sie diese E-Mail-Adresse für alle Anfragen.</code>"  
        
    elif languageButton.value == "italiano":
        sujet = "Registrazione come richiedente sulla piattaforma di domanda ISO12215:2019" 
        html = "Ciao,<br><br>Grazie per aver utilizzato i nostri servizi. Ora puoi presentare una o più richieste di controllo.<br>\
        Conserva i dati che ti inviamo in un luogo sicuro. Questi dati dovrebbero essere presentati\
        in modo da poter studiare qualsiasi richiesta relativa ai dati forniti al termine del controllo.\
        <br>Infine, ti ricordiamo che il controller che stai utilizzando è un automa creato\
        su vostra richiesta, da A.C.E. CATTELLIOT ENGINEERING e di cui ti concediamo\
        un limitato utilizzo. <br><br><b><u>Questo automa è personale per te (computer virtuale inaccessibile dall'esterno).\
        quando viene cancellato, i dati del modulo, i dati scambiati e i dati di archiviazione vengono cancellati.</u></b>\
        Ai fini del controllo interno, ci viene inviata una copia di questa lettera.<br><br>\
        Vi auguriamo buon uso dei nostri servizi. In caso di domande, non esitare\
        per contattarci. La nostra giovane azienda si dedica alla creazione\
        il collegamento pratico tra tutti gli attori della nautica da diporto e siamo sempre interessati a conoscere il tuo\
        problemi specifici.\
        <br><br>\
        Cordiali saluti,\
        <br><br><br><br><br>\
        <codice>A.C.E. CATTELLIOT ENGINEERING è una società di servizi per la nautica da diporto e le regate d'altura, affiliata alla Federazione delle Industrie Nautiche,\
        approvato contrattualmente con l'organismo notificato ENAVE, nei settori <b>Nautica, Offshore Racing</b>.<br>\
        Utilizza questo indirizzo email per tutte le richieste.</code>"  
                
    elif languageButton.value == "español":
        sujet = "Registro como solicitante en la plataforma de aplicación ISO12215:2019" 
        html = "Hola,<br><br>Gracias por utilizar nuestros servicios. Ahora puede presentar una o más solicitudes de control.<br>\
        Guarda los datos que te enviamos en un lugar seguro. Estos datos deben ser presentados\
        para que podamos estudiar cualquier solicitud relativa a los datos facilitados al finalizar el control.\
        <br>Por último, te recordamos que el controlador que estás utilizando es un autómata creado\
        a petición suya, por A.C.E. CATTELLIOT ENGINEERING y de los cuales te otorgamos\
        una utilización limitada. <br><br><b><u>Este autómata es personal para usted (computadora virtual inaccesible desde el exterior).\
        cuando se elimina, se eliminan los datos del formulario, los datos intercambiados y los datos de almacenamiento.</u></b>\
        Para fines de control interno, se nos envía una copia de esta carta.<br><br>\
        Le deseamos un buen uso de nuestros servicios. Si tiene alguna pregunta, no dude en \
        para contactarnos. Nuestra joven empresa se dedica a crear\
        el vínculo práctico entre todos los jugadores de la navegación, y siempre estamos interesados ​​​​en conocer su \
        problemas específicos.\
        <br><br>\
        Muy cordialmente,\
        <br><br><br><br><br>\
        <código>A.C.E. CATTELLIOT ENGINEERING es una empresa de servicios para la navegación a vela y regatas oceánicas, afiliada a la Federación de Industrias Náuticas,\
        homologado por contrato con el organismo notificado ENAVE, en los sectores <b> la Navegación de Recreo, Offshore Racing</b>.<br>\
        Utilice esta dirección de correo electrónico para todas las consultas.</code>" 
    
    sendEmail(sujet,html,'')

    
    

def confirm_Product(change):
    confirmProductButton.button_style='success'
    confirmProductButton.description ='Identified'
    confirmProductButton.disabled = True
    check_Contract(True)
    
def confirm_Contract(change):
    global contractIcone
    confirmContractButton.button_style='success'
    confirmContractButton.description ='Accepted'
    confirmContractButton.disabled = True
    contractZone.value = contractIcone
    update_value(True)
    
    if languageButton.value == 'english':
        sujet = "ISO12215:2019 Application Results for " + matiereButton.value
    elif languageButton.value == 'français':
        sujet = "Résultats de l'application ISO12215:2019 pour " + matiereButton.value
    elif languageButton.value == "deutsch":
        sujet = "ISO12215:2019 Anwendungsergebnisse für " + matiereButton.value 
    elif languageButton.value == "italiano":
        sujet = "Risultati dell'applicazione ISO12215:2019 per " + matiereButton.value 
    elif languageButton.value == "español":
        sujet = "ISO12215:2019 Resultados de la aplicación para" + matiereButton.value 
    
    sendEmail(sujet, details.value + g.value,'')
    
    if languageButton.value == 'english':
        sujet = "ISO12215:2019 Application Certificates for " + matiereButton.value 
    elif languageButton.value == 'français':
        sujet = "Certificats de l'application ISO12215:2019 pour " + matiereButton.value
    elif languageButton.value == "deutsch":
        sujet = "ISO12215:2019 Anwendungszertifikate für " + matiereButton.value 
    elif languageButton.value == "italiano":
        sujet = "Certificati di domanda ISO12215:2019 per " + matiereButton.value
    elif languageButton.value == "español":
        sujet = "Certificados de aplicación ISO12215:2019 para " + matiereButton.value
     
    sendEmail(sujet, f.value,'')
    
#if (submitterNameButton.value =! "")\
#    and (submitterAdress.value =! "")\
#    and (submitterTown.value =! "")\
#    and (submitterPost.value =! "")\
#    and (submitterCountry.value =! "")\
#    and (emailForm.value =! ""):    

menu3 = HBox([serverOutput,sendemailButton,]) 
submitterForm = HBox([submitterNameButton,submitterFirstNameButton,submitterAdress,submitterTown,submitterPost,submitterCountry,emailForm],layout = form_layoutboxed )
productForm = HBox([uniteButton,modeleButton,WINBUTTON,architecteButton,listeDesignCategoryButton,lwlButton,mldcButton],layout = form_layoutboxed )

# %%
###CONTROL CONTENT

Title42 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title43 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title44 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title45 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title455 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title456 = widgets.HTML(
        value="<font size=3> DESCRIPTION</font>",
        placeholder='',
        description='',
)



Title42.value = "<font size=1>code</font>"

Title43.value = "<font size=1>requirements to be assessed</font>"

Title44.value ="<font size=1>standard reference</font>"

Title455.value ="<font size=1>subject</font>"

Title45.value ="<font size=1> importance</font>"

controlForm2 = HBox([Title455,Title42,Title44,Title43,Title45],layout = head_display2_layout)

controlForm1 = HBox([controlButton,matiereButton,contextButton],layout = form_layoutboxed)

#

# %%
###LIST OF ATTACHED DOCUMENT DOCUMENTS // FICHE MATIERE ACE CATTELLIOT ENGINEERING

Title46 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title47 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title48 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title49 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)

Title50 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)
Title500 = widgets.HTML(
        value="<font size=3> TECHNICAL DOCUMENTATION</font>",
        placeholder='',
        description='',
)
Title501 = widgets.HTML(
        value="",
        placeholder='',
        description='',
)

Title46.value = "<font size=1>file name</font>"

Title47.value = "<font size=1>form type</font>"

Title48.value = "<font size=1>form date</font>"

Title49.value = "<font size=1>form source</font>"
Title50.value = "<font size=1>status</font>"
Title501.value = "<font size=1>category</font>"

# %%
controlForm3 = HBox([Title46,Title47,Title48,Title49,Title501, Title50],layout = head_display2_layout)

# %%
controlForm4 = HBox([submitname3],layout = head_display2_layout)

# %%
def calculate_Bc(lwl,mldc,delta):
    a = 0.084*0.32*delta*lwl
    b = 0.032*delta*lwl**2
    c = -3/25*mldc
    Bc = (-1*b+(b**2-4*a*c)**.5)/2/a
    V = 5*lwl**0.5
    
    return Bc,V

# %%
def calculate_kdyn(lwl,mldc,bc,delta,V):
    kdyn = 24**.5/mldc**0.17*2.5
    kdyn = 0.32*(lwl/10/bc+0.084)*delta*V**2*bc**2/mldc
    return kdyn

# %%
def tableA7_requirements(methode,lwl,mldc):

    #tau0 contrainte intermédiaire de calcul
    #tau1 contrainte après imposition de la valeur minimale pour la resistance
    #tau2 resistance minimale en cisaillement 2019
    #tau3 resistance minimale en cisaillement 2008
    
    #Tau as a function of lwl 2019 modified by G.Dolto
    tau0 = b-a*lwl
    tau0_max = lwl*0+0.3
    tau1_min = lwl*0+0.58
    tau1 = max(tau0,tau0_max)
    tau2 = min(tau1,tau1_min)
    #Tau as a function of lwl 2008
    if lwl<10:
            tau3 = 0.25
    elif lwl>15:
            tau3 = 0.40
    else:
            tau3 = 0.25+0.03*(lwl-10)
        
    ksls = 1
    bc, V = calculate_Bc(lwl,mldc,38)
    kdyn = 3
    
    
    
    #Sigma as a function of mldc 2019 as required for displacement motor in ABCD
    sigma1 = 0.008 * (2.4*mldc**0.33+20)
    #Sigma as a function of mldc 2019 as required for planning motor in A
    sigma2 = 0.008*0.1*mldc/lwl/bc*(1+kdyn)
    #Sigma as a function of mldc 2019 as required for planning motor in B
    sigma3 = 0.008*0.1*mldc/lwl/bc*(1+0.8**.5*kdyn)
    #Sigma as a function of mldc 2019 as required for planning motor in C
    sigma4 = 0.008*0.1*mldc/lwl/bc*(1+0.6**.5*kdyn)
    #Sigma as a function of mldc 2019 as required for planning motor in C
    sigma5 = 0.008*0.1*mldc/lwl/bc*(1+0.4**.5*kdyn)
    #Sigma as a function of mldc 2019 as required for sailing in ABCD
    sigma6 = 0.008*(2*mldc**.33+18)*ksls
    
    
    #if methode == "Méthode 1 (Simplifiée)":
    #    kAM = 0.90
    #elif methode == "Méthode 2 (Développée) analyse pli par pli":
    #    kAM = 0.95
    #else:
    #    kAM = 1
    kAM = 1
             

    
    return tau2,tau3,sigma1,sigma2,sigma3,sigma4,sigma5,sigma6,kAM,ksls,kdyn,bc,V

# %%
def update_value(change):
    
    global table
    global valid2019
    global newunvalid
    global taudcomin2019,taudcomin2008,d_abcd_sigmadccomin2019,p_a_sigmadccomin2019,p_b_sigmadccomin2019,p_c_sigmadccomin2019,p_d_sigmadccomin2019,v_abcd_sigmadccomin2019,kAM,ksls,kdyn, Bc, V
    global html
    global demonstrationObject
    global i
    
    #Numérise
    # a and b from modified

    a = -0.07
    b = -0.12
    taudcomin2019,taudcomin2008,d_abcd_sigmadccomin2019,p_a_sigmadccomin2019,p_b_sigmadccomin2019,p_c_sigmadccomin2019,p_d_sigmadccomin2019,v_abcd_sigmadccomin2019,kAM,ksls,kdyn, Bc,V = tableA7_requirements(methodeButton.value,lwlButton.value,mldcButton.value)
    table["τd"]=[""]*27
    table["σd"]=[""]*27
    for i in range(len(table)):
        try:
            val = float(table.loc[i,"εuf1b"])
            if val <= 0.35:
                table.loc[i,"τd"]=float(table.loc[i,"τ12"])*0.55*.90
                table.loc[i,"σd"]=float(table.loc[i,"σuc1"])*0.55*.90
            elif val > 0.35:
                table.loc[i,"τd"]=float(table.loc[i,"τ12"])*0.65*.90
                table.loc[i,"σd"]=float(table.loc[i,"σuc1"])*0.65*.90
        except ValueError:
            table.loc[i,"τd"]=float(table.loc[i,"τ12"])*0.50*.90
            table.loc[i,"σd"]=float(table.loc[i,"σuc1"])*0.50*.90
    
    
    if modeleTypeButton.value =="Moteur à déplacement":
        valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>d_abcd_sigmadccomin2019/kAM),"Reference"].tolist()
        newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
        newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=d_abcd_sigmadccomin2019/kAM),"Reference"].tolist()
        newunvalid = newunvalid1 + newunvalid2
    elif modeleTypeButton.value =="Voilier":
        valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>v_abcd_sigmadccomin2019/kAM),"Reference"].tolist()
        newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
        newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=v_abcd_sigmadccomin2019/kAM),"Reference"].tolist()
        newunvalid = newunvalid1 + newunvalid2
    else:
        if listeDesignCategoryButton.value == "A":
            valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>p_a_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
            newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=p_a_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid = newunvalid1 + newunvalid2
        elif listeDesignCategoryButton.value == "B":
            valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>p_b_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
            newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=p_b_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid = newunvalid1 + newunvalid2
        elif listeDesignCategoryButton.value == "C":
            valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>p_c_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
            newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=p_c_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid = newunvalid1 + newunvalid2
        elif listeDesignCategoryButton.value == "D": 
            valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>p_d_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
            newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=p_d_sigmadccomin2019/kAM),"Reference"].tolist()
            newunvalid = newunvalid1 + newunvalid2
    
    #shorted = ""
    #for i in valid2019:
    #    shorted = shorted + ", " + i
    
    shorted = ', '.join(valid2019)
    excluded = ', '.join(newunvalid)
    
    #excluded = ""
    #for i in newunvalid:
    #    excluded = excluded + ", " + i
   
    
    indexchoisi = table[table["Reference"]== matiereButton.value]
    i = indexchoisi.index.values[0]
    
    if languageButton.value == 'english':
         
        demonstration, demonstrationObject = demonstrate_ENG(i)
        
      
    elif languageButton.value == 'français':
        phrase5 = "<br>\
        <font size=4>Important</font><br> La qualification EN-ISO-12215:2019 des matériaux dépend fortement de leur utilisation finale par le fabricant, qui doit en tenir compte\
        les formes précises du navire et leurs mesures,\
        ainsi que le domaine d'utilisation pour lequel il est déclaré.<br>\
        <b>Cette qualification des matériaux doit être vérifiée au cas par cas</b> et cette vérification doit être répétée <b>à chaque mise à jour du produit</b>. Ce contrôle peut entraîner une perte de qualification du matériel.<br>\
        "
        demonstration, demonstrationObject = demonstrate(i)
        demonstration = demonstration\
        + phrase5
    elif languageButton.value == "deutsch":
        
        demonstration, demonstrationObject = demonstrate_ENG(i)
       
    elif languageButton.value == "italiano":
        
        demonstration, demonstrationObject = demonstrate_ENG(i)
       
    elif languageButton.value == "español":
        
        demonstration, demonstrationObject = demonstrate_ENG(i)
    
    
    certificate = create_certificate(True)
    
    change_language(True)
    
    if languageButton.value == 'english':
        phrase1 = "<font size=4><br>Settings</font><font size=2>"
        phrase2 = "<font size=2>The following additionnal references have been used :"
        phrase3 = "<font size=4><br>Additional Notes</font><br>"
        phrase4 ="<font size=2>Please note that calculations in planning mode are made with the following parameters :  Boat velocity in fully loaded condition V = " +  str('{:.1f}'.format(V))+ "kts,   Chine beam/angle bc/β = "  +str('{:.2f}'.format(Bc)) + "m/" + str('{:.2f}'.format(12)) + "° \
        in consistency with the given value of kDYN. Every couple of values (bc,β) for which\
        the kDYN value is 3.0±1%  will produce the same evaluation. Please refer to an official publication\
        of the standard reference §8.3 for further explanations. <br><br></font>" 
    elif languageButton.value == 'français':
        phrase1 = "<font size=4><br>Paramètres</font><font size=2>"
        phrase2 = "<font size=2>Les références additionnelles ont été utilisées:"
        phrase3 = "<font size=4><br>Remarques additionnelles</font><br>"
        phrase4 = "<font size=2>Veuillez noter que les calculs en mode planification sont effectués avec les paramètres suivants : Vitesse du bateau à pleine charge V = " + str('{:.1f}'.format(V))+ "kts, Bau au bouchain/angle bc/β = " +str('{:.2f}'.format(Bc)) + "m/" + str('{:.2f}'.format(12)) + "° \
        en cohérence avec la valeur donnée de kDYN. Chaque couple de valeurs (bc,β) pour lequel\
        la valeur kDYN est de 3,0 ± 1 % produira la même évaluation. Veuillez vous référer à une publication officielle\
        de la référence normative §8.3 pour plus d'explications. <br><br></font>" 
      
    elif languageButton.value == "deutsch":
        phrase1 = "<font size=4><br>Einstellungen</font><font size=2>"
        phrase2 = "<font size=2>Folgende zusätzliche Referenzen wurden verwendet:"
        phrase3 = "<font size=4><br>Zusätzliche Hinweise</font><br>" 
        phrase4 = "<font size=2>Bitte beachten Sie, dass Berechnungen im Planungsmodus mit folgenden Parametern durchgeführt werden: Bootsgeschwindigkeit bei Volllast V = " + str('{:.1f}'.format(V))+ "kts , Kimmenbreite/Winkel bc/β = " +str('{:.2f}'.format(Bc)) + "m/" + str('{:.2f}'.format(12)) + " °\
        konsistent mit dem gegebenen Wert von kDYN. Jedes Wertepaar (bc,β), für das\
        Ein kDYN-Wert von 3,0 ± 1 % ergibt dieselbe Schätzung. Bitte beziehen Sie sich auf eine offizielle Veröffentlichung\
        der normativen Referenz §8.3 für weitere Erläuterungen. <br><br></font>" 
    elif languageButton.value == "italiano":
        phrase1 = "<font size=4><br>Impostazioni</font><font size=2>"
        phrase2 = "<font size=2>Sono stati utilizzati i seguenti riferimenti aggiuntivi:"
        phrase3 = "<font size=4><br>Note aggiuntive</font><br>"
        phrase4 = "<font size=2>Si noti che i calcoli in modalità pianificazione vengono eseguiti con i seguenti parametri: Velocità dell'imbarcazione a pieno carico V = " + str('{:.1f}'.format(V))+ "kts ,  larghezza di sentina/angle bc/β = " +str('{:.2f}'.format(Bc)) + "m/" + str('{:.2f}'.format(12)) + " °\
        coerente con il valore dato di kDYN. Ogni coppia di valori (bc,β) per cui\
        Il valore kDYN è 3,0 ± 1% produrrà la stessa stima. Fare riferimento a una pubblicazione ufficiale\
        del riferimento normativo §8.3 per maggiori precisazioni. <br><br></font>" 
        
    elif languageButton.value == "español":
        phrase1 = "<font size=4><br>Configuración</font><font size=2>"
        phrase2 = "<font size=2>Se usaron las siguientes referencias adicionales:"
        phrase3 = "<font size=4><br>Notas adicionales</font><br>" 
        phrase4 = "<font size=2>Tenga en cuenta que los cálculos en el modo de planificación se realizan con los siguientes parámetros: Velocidad del barco a plena carga V = " + str('{:.1f}'.format(V))+ "kts , ancho de patoque/ángulo bc/β = " +str('{:.2f}'.format(Bc)) + "m/" + str('{:.2f}'.format(12)) + " °\
        consistente con el valor dado de kDYN. Cada par de valores (bc,β) para los que\
        El valor kDYN es 3,0 ± 1% producirá la misma estimación. Consulte una publicación oficial\
        de la referencia normativa §8.3 para más explicaciones. <br><br></fuente>" 

    
    if confirmContractButton.description =="Accepted":
        details.value = demonstration
        g.value = phrase1\
        + "<br>"\
        + "<table>"\
        + "<tr><td>"\
        + "Type"\
        + "</td><td>&nbsp;"\
        + modeleTypeButton.value\
        + "</td></tr>"\
        + "<tr><td>"\
        + listeDesignCategoryButton.description\
        + "</td><td>&nbsp;"\
        + listeDesignCategoryButton.value\
        + "</td></tr>"\
        + "<tr><td>"\
        + lwlButton.description\
        + "</td><td>&nbsp;"\
        + str('{:.2f}'.format(lwlButton.value))\
        + "</td></tr>"\
        + "<tr><td>"\
        + mldcButton.description\
        + "</td><td>&nbsp;"\
        + str('{:.0f}'.format(mldcButton.value))\
        + "</td></tr>"\
        + "<tr><td>"\
        + "kAM"\
        + "</td><td>&nbsp;"\
        + str('{:.1f}'.format(1))\
        + "</td></tr>"\
        + "<tr><td>"\
        + "kSLS"\
        + "</td><td>&nbsp;"\
        + str('{:.1f}'.format(1))\
        + "</td></tr>"\
        + "<tr><td>"\
        + "kDYN"\
        + "</td><td>&nbsp;"\
        + str('{:.1f}'.format(3))\
        + "</td></tr>"\
        + "</table></font>"\
        
        g.value = g.value + phrase2\
        + "<br>\
        ▪ EN ISO 12215-5:2019 §10<br>\
        ▪ EN ISO 12215-5:2019 Table 17<br>\
        ▪ EN ISO 12215-5:2008 Table 16<br>\
        ▪ WG 18 ERRATA/IMPROVEMENT LIST/APPLICATION GUIDE IN ISO 12215 SERIES du 2021-12-06, G. Dolto, §4.17</font><br>"
        
        if modeleTypeButton.value == "Moteur planant":
            g.value = g.value + phrase4   
        
        g.value = g.value + phrase3\
        + "<font size=2><b>2019 compliant</b><br>"+shorted+ "<br>"+"<b>2019 excluded</b><br>" + excluded + "</font>"
        
        
        f.value = certificate
    else:
        details.value = ""
        g.value =""
        f.value =""
    
    html = """\
    <html>
    <head>
    <meta charset="utf-8" />
    </head>
    <body>
    <div>
    """
    html = html+details.value + "</div></body></html>"
   
    
    with display.batch_update():
        display.data[4].x = [d_abcd_sigmadccomin2019/kAM,d_abcd_sigmadccomin2019/kAM,4.5,4.5]
        display.data[4].y = [taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM]
        display.data[5].x = [0.2,0.2,4.5,4.5]
        display.data[5].y = [taudcomin2008,1.0,1.0,taudcomin2008]
        display.data[6].x = [p_a_sigmadccomin2019/kAM,p_a_sigmadccomin2019/kAM,4.5,4.5]
        display.data[6].y = [taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM]
        display.data[7].x = [p_b_sigmadccomin2019/kAM,p_b_sigmadccomin2019/kAM,4.5,4.5]
        display.data[7].y = [taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM]
        display.data[8].x = [p_c_sigmadccomin2019/kAM,p_c_sigmadccomin2019/kAM,4.5,4.5]
        display.data[8].y = [taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM]
        display.data[9].x = [p_d_sigmadccomin2019/kAM,p_d_sigmadccomin2019/kAM,4.5,4.5]
        display.data[9].y = [taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM]
        display.data[10].x = [v_abcd_sigmadccomin2019/kAM,v_abcd_sigmadccomin2019/kAM,4.5,4.5]
        display.data[10].y = [taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM]
        fig2.data[0].cells.values = [[shorted], # 1st column
                       [excluded]]

# %%
def create_certificate(change):
    
    global demonstrationObject
    global table
    global resultatcontrol
    
    
    if languageButton.value == 'english':
        phrase1 = "The designated core material <font size=2><b><u>"
        phrase2 = ", according to the reference standard <font size=2><b><u>"
        
    elif languageButton.value == 'français':
        phrase1 = "Le matériau de base désigné <font size=2><b><u>"
        phrase2 = ", selon la norme de référence <font size=2><b><u>"
              
    elif languageButton.value == "deutsch":
        phrase1 = "Das festgelegte Kernmaterial <font size=2><b><u>"
        phrase2 = ", nach dem Referenzstandard <font size=2><b><u>" 
         
        
    elif languageButton.value == "italiano":
        phrase1 = "Il materiale di base designato <font size=2><b><u>"
        phrase2 = ", secondo lo standard di riferimento <font size=2><b><u>" 
         
                
    elif languageButton.value == "español":
        phrase1 = "El material central designado <font size=2><b><u>"
        phrase2 = ", según el estándar de referencia <font size=2><b><u>" 
    
    certificate =\
    Title411.value\
    + "<br><font size=5>"\
    + controlButton.value\
    + "<br><br>"\
    + Title1.children[0].value\
    + "</font>"\
    + "<table>"\
    + "<tr><td>"\
    + submitterNameButton.description\
    + "</td><td>&nbsp;"\
    + submitterNameButton.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + submitterAdress.description\
    + "</td><td>&nbsp;"\
    + submitterAdress.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + submitterPost.description\
    + "</td><td>&nbsp;"\
    + submitterPost.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + submitterTown.description\
    + "</td><td>&nbsp;"\
    + submitterTown.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + submitterCountry.description\
    + "</td><td>&nbsp;"\
    + submitterCountry.value\
    + "</td></tr>"\
    +"</table><br>"\
    + Title2.children[0].value\
    + "<table>"\
    + "<tr><td>"\
    + "Type"\
    + "</td><td>&nbsp;"\
    + modeleTypeButton.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + uniteButton.description\
    + "</td><td>&nbsp;"\
    + uniteButton.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + modeleButton.description\
    + "</td><td>&nbsp;"\
    + modeleButton.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + WINBUTTON.description\
    + "</td><td>&nbsp;"\
    + WINBUTTON.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + listeDesignCategoryButton.description\
    + "</td><td>&nbsp;"\
    + listeDesignCategoryButton.value\
    + "</td></tr>"\
    + "<tr><td>"\
    + lwlButton.description\
    + "</td><td>&nbsp;"\
    + str('{:.2f}'.format(lwlButton.value))\
    + "</td></tr>"\
    + "<tr><td>"\
    + mldcButton.description\
    + "</td><td>&nbsp;"\
    + str('{:.0f}'.format(mldcButton.value))\
    + "</td></tr>"\
    + "</table>"\
    + "<br>"\
    + controlForm4.children[0].value\
    + "<br>"\
    + Title4.children[0].value\
    + demonstrationObject\
    + "<br>"\
    + phrase1\
    + matiereButton.value \
    + "</u></b></font>\
    has been evaluated using the PROCEDURE of evaluation <font size=2><b><u>"\
    + controlButton.value\
    + "</u></b></font><br>"\
    + resultatcontrol\
    + phrase2\
    + listeControls[listeControls['Nom'] == controlButton.value].Reference.tolist()[0] \
    + ""\
    + listeControls[listeControls['Nom'] == controlButton.value].Title.tolist()[0] \
    + "</u></b></font>"


    return certificate

# %%
def control_resultat():
    
    global Bc, table, i
    
    if languageButton.value == 'english':
        phrase1 = "<font size=4>Conclusion</font><br><b><u>"
        okpass = " -Pass- "
        kopass = " -Fail- "
        phrase3 = ",with a margin of "
        phrase4 = "% in compressive strenght and a margin of "
        phrase5 = "% in shear strenght.</b></u>"
        
    elif languageButton.value == 'français':
        phrase1 = "<font size=4>Conclusion</font><br><b><u>"
        okpass = " -Succès- "
        kopass = " -Échec- "
        phrase3 = ", avec une marge de "
        phrase4 = "% de résistance à la compression et une marge de "
        phrase5 = "% de résistance au cisaillement.</b></u>"
        
              
    elif languageButton.value == "deutsch":
        phrase1 = "<font size=4>Fazit</font><br><b><u>"
        okpass = " -Bestandene- "
        kopass = " -Nicht bestandene- "
        phrase3 = "mit einem Rand von "
        phrase4 = "% an Druckfestigkeit und eine Spanne von "
        phrase5 = "% Scherfestigkeit.</b></u>"
         
        
    elif languageButton.value == "italiano":
        phrase1 = "<font size=4>Conclusione</font><br><b><u>"
        okpass = " -Positivo- "
        kopass = " -Fallito- "
        phrase3 = ",con un margine di "
        phrase4 = "% di resistenza alla compressione e un margine di "
        phrase5 = "% in resistenza al taglio.</b></u>"
         
                
    elif languageButton.value == "español":
        phrase1 = "<font size=4>Conclusión</font><br><b><u>"
        okpass = "-Exitosa-"
        kopass = "-Fallo-"
        phrase3 = ",con un margen de"
        phrase4 = "% en resistencia a la compresión y un margen de "
        phrase5 = "% en resistencia al corte.</b></u>"
        
    
    
    resultatcontrol = phrase1
    
    
    if modeleTypeButton.value =="Moteur à déplacement":
            if (table.loc[i,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[i,"τd"]>taudcomin2019/kAM):
                resultatcontrol = resultatcontrol +  okpass
                
            else:
                 resultatcontrol = resultatcontrol +  kopass
            margin1=table.loc[i,"σd"]/d_abcd_sigmadccomin2019/kAM*100
            margin2=table.loc[i,"τd"]/taudcomin2019/kAM*100
    
    elif modeleTypeButton.value =="Voilier":
            if (table.loc[i,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[i,"τd"]>taudcomin2019/kAM):
                resultatcontrol = resultatcontrol +  okpass
            else:
                resultatcontrol = resultatcontrol +  kopass
            margin1=table.loc[i,"σd"]/v_abcd_sigmadccomin2019/kAM*100
            margin2=table.loc[i,"τd"]/taudcomin2019/kAM*100
    else:
        if listeDesignCategoryButton.value == "A":
            if (table.loc[i,"σd"]>p_a_sigmadccomin2019/kAM) & (table.loc[i,"τd"]>taudcomin2019/kAM):
                 resultatcontrol = resultatcontrol +  okpass
            else:
                 resultatcontrol = resultatcontrol +  kopass
            margin1=table.loc[i,"σd"]/p_a_sigmadccomin2019/kAM*100
            margin2=table.loc[i,"τd"]/taudcomin2019/kAM*100
        
        elif listeDesignCategoryButton.value == "B":
            if (table.loc[i,"σd"]>p_b_sigmadccomin2019/kAM) & (table.loc[i,"τd"]>taudcomin2019/kAM):
                resultatcontrol = resultatcontrol +  okpass
            else:
                resultatcontrol = resultatcontrol +  kopass    
            margin1=table.loc[i,"σd"]/p_b_sigmadccomin2019/kAM*100
            margin2=table.loc[i,"τd"]/taudcomin2019/kAM*100
            
        elif listeDesignCategoryButton.value == "C":
            if (table.loc[i,"σd"]>p_c_sigmadccomin2019/kAM) & (table.loc[i,"τd"]>taudcomin2019/kAM):
                resultatcontrol = resultatcontrol +  okpass
            else:
                resultatcontrol = resultatcontrol +  kopass
            margin1=table.loc[i,"σd"]/p_c_sigmadccomin2019/kAM*100
            margin2=table.loc[i,"τd"]/taudcomin2019/kAM*100
            
        elif listeDesignCategoryButton.value == "D": 
    
            if (table.loc[i,"σd"]>p_d_sigmadccomin2019/kAM) & (table.loc[i,"τd"]>taudcomin2019/kAM):
                resultatcontrol = resultatcontrol +  okpass
            else:
                resultatcontrol = resultatcontrol +  kopass                
            margin1=table.loc[i,"σd"]/p_c_sigmadccomin2019/kAM*100
            margin2=table.loc[i,"τd"]/taudcomin2019/kAM*100

    resultatcontrol = resultatcontrol\
    + phrase3\
    + str('{:.0f}'.format(margin1))\
    + phrase4\
    + str('{:.0f}'.format(margin2))\
    + phrase5
    
    return resultatcontrol

# %%
def demonstrate(index,):
    
    global Bc, table,resultatcontrol
    
    #demonstration
    demonstration = "<font size=4>"+table.loc[index,"Reference"]+"</font><br>│"
    demonstration = demonstration + '{:>50} : {:>10}│'.format(
        "Matiere",
        table.loc[index,"Matiere"]
    )
    demonstration = demonstration + '{:>50} : {:>10}kg/m3│'.format(
        "Masse volumique ρ",
        table.loc[index,"Masse volumique ρ"]
    )
    demonstration = demonstration + '{:>10} : {:>10}│'.format(
        "Elongation à la rupture",
        table.loc[index,"εuf1b"]
    )
    demonstration = demonstration + '{:>50} : {:>10}MPa│'.format(
        "Resistance en cisaillement plan, à la rupture",
        table.loc[index,"τ12"]
    )
    demonstration = demonstration + '{:>10} : {:>10}MPa│'.format(
        "Resistance en compression normale, à la rupture",
        table.loc[index,"σuc1"]
    )
    
    demonstrationObject = demonstration
    demonstration = demonstration + "<br><br>"
    
    resultatcontrol = control_resultat()
    
    demonstration = demonstration  + resultatcontrol + "<br><br>"
 
    
    demonstration = demonstration + "\
    &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; D&nbsp;&nbsp;&nbsp;&nbsp; P&nbsp;&nbsp;&nbsp;&nbsp; V&nbsp;&nbsp;&nbsp;&nbsp;<BR>\
    " 
    
    demonstration = demonstration + "\
    <font size=2>Catégorie A&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_a_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    "
    
    demonstration = demonstration + "\
    <font size=2>Catégorie B&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_b_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    "
    
    demonstration = demonstration + "\
    <font size=2>Catégorie C&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_c_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    "
    
    demonstration = demonstration + "\
    <font size=2>Catégorie D&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_d_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    (D) Moteur à déplacement, (P) Moteur plannant, (V) Voilier <br>\
    (■) Qualifié ISO2019, (□) Dé-qualifié ISO2019, (-) Non qualifié ISO2019, ni ISO2008<br>\
    "
    
    
    demonstration = demonstration + "<br>\
    <font size=2>\
    "
    demonstration = demonstration + "\
        ▪ Résistance minimum en cisaillement dans le plan τdco,min = \
    "
    demonstration = demonstration + str('{:.2f}'.format(taudcomin2019)) + "MPa " + "<code> min(max(" + str(b) + "-" + str(a) + " x " + str(lwlButton.value) +  ", 0.3), 0.58)</code><br>"
    demonstration = demonstration + "\
        ▪ Résistance minimum en compression dans le sens normal σdcco,min = \
    "
                    
    if modeleTypeButton.value =="Moteur à déplacement":
        demonstration = demonstration + str('{:.2f}'.format(d_abcd_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x (2.4 x "+ str('{:.0f}'.format(mldcButton.value))+ "^0.33+20)</code><br>"
    elif modeleTypeButton.value =="Voilier":
        demonstration = demonstration + str('{:.2f}'.format(v_abcd_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x (2.0 x "+ str('{:.0f}'.format(mldcButton.value))+ "^0.33+18)*1.0</code><br>"
    else:
        if listeDesignCategoryButton.value == "A":
            demonstration = demonstration + str('{:.2f}'.format(p_a_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+1.0 x 3.0))</code><br>"
    
        elif listeDesignCategoryButton.value == "B":
            demonstration = demonstration + str('{:.2f}'.format(p_b_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+0.8 x 3.0))</code><br>"
    
        elif listeDesignCategoryButton.value == "C":
            demonstration = demonstration + str('{:.2f}'.format(p_c_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+0.6 x 3.0))</code><br>"
    
        elif listeDesignCategoryButton.value == "D": 
             demonstration = demonstration + str('{:.2f}'.format(p_d_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+0.4 x 3.0))</code><br>"
    
    
    demonstration = demonstration + "\
        ▪ Résistance minimum en cisaillement dans le plan τdco,min2008 = \
    "
    demonstration = demonstration + str('{:.2f}'.format(taudcomin2008))+ "MPa " + "<code> min(max(0.25 + 0.03 x ("+ str(lwlButton.value) +  " - 10), 0.25), 0.40)</code><br>"
    
    try:
        
        val = float(table.loc[index,"εuf1b"])
        if val <= 0.35:
            demonstration = demonstration + "\
            ▪ Contrainte de conception en cisaillement plan τdco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"τd"])) + "MPa "
            demonstration = demonstration + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 "  + str(float(table.loc[index,"εuf1b"])<0.35)+ ", 0.55 x 0.9 x" + str(table.loc[index,"τ12"]) + "</code>.<br> "
            demonstration = demonstration + "\
            ▪ Contrainte de conception en compression normale σdcco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"σd"])) + "MPa "
            demonstration = demonstration + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.55 x 0.9 x" + str(table.loc[index,"σuc1"]) + "</code></font>.<br> "      
            
            
        elif val > 0.35:
            demonstration = demonstration + "\
            ▪ Contrainte de conception en cisaillement plan τdco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"τd"])) + "MPa " + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.65 x 0.9 x" + str(table.loc[index,"τ12"]) + "</code>.<br> "
            demonstration = demonstration + "\
            ▪ Contrainte de conception en compression normale σdcco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"σd"])) + "MPa " + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.65 x 0.9 x" + str(table.loc[index,"σuc1"]) + "</code></font>.<br> "
    except ValueError:
        demonstration = demonstration + "\
        ▪ Contrainte de conception en cisaillement plan τdco = \
        "
        demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"τd"])) + "MPa " + "<code>  " + "balsa core " + str(True) + ", 0.50 x 0.9 x" + str(table.loc[index,"τ12"]) + "</code>.<br> "
        demonstration = demonstration + "\
        ▪ Contrainte de conception en compression normale σdcco = \
        "
        demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"σd"])) + "MPa " + "<code>  " + "balsa core " + str(True) + ", 0.50 x 0.9 x" + str(table.loc[index,"σuc1"]) + "</code></font>.<br> "
   

    
    return demonstration, demonstrationObject

# %%
def demonstrate_ENG(index,):
    
    global Bc, table,resultatcontrol,importantenotice
    
    
    if languageButton.value == 'english':
        importantenotice = "<br>\
        <font size=4>Important</font><br> The EN-ISO-12215:2019 qualification of materials strongly depends on their end use by the manufacturer, who must take into account\
        the precise shapes of the ship and their measurements,\
        as well as the field of use for which it is declared.<br>\
        <b>This qualification of materials must be checked on a case-by-case basis</b> and this check must be repeated <b>at each product update</b>. This control can result in a loss of qualification of the material.<br>\
        "
        legend1 = "(D) Displacement motorcraft, (P) Planning motorcraft, (S) sailing craft <br>\
        (■) ISO2019 compliant, (□) ISO2008-2019 failed, (-) ISO2019 & ISO2008 failed<br>\
        "
        
    elif languageButton.value == 'français':
        importantenotice = "<br>\
        <font size=4>Important</font><br> La qualification EN-ISO-12215:2019 des matières dépends fortement de leur usage final par le constructeur. Ce dernier doit prendre en compte\
        les formes précises du navire et leurs mesures,\
        ainsi que le domaine d'utilisation pour lequel il est déclaré.<br>\
        <b>Cette qualification des matières doit être contôlée au cas par cas</b> et ce contrôle doit être ré-itéré <b>à chaque mise à jour du produit</b>. Ce contôle peut se conclure par une perte de la qualification de la matière.<br>\
        "
        legend1 = "(D) Bateau à moteur à déplacement, (P) Bateau à moteur planant, (V) Voilier <br>\
        (■) Qualifié ISO2019, (□) Dé-qualifié par ISO2019, (-) Non qualifié ISO2019, ni ISO2008<br>\
        "
              
    elif languageButton.value == "deutsch":
        importantenotice = "<br>\
        <font size=4>Wichtig</font><br> Die EN-ISO-12215:2019-Qualifizierung von Materialien hängt stark von ihrer Endverwendung durch den Hersteller ab, der berücksichtigt werden muss\
        die genauen Formen des Schiffes und ihre Maße,\
        sowie den Einsatzbereich, für den es deklariert ist.<br>\
        <b>Diese Qualifizierung der Materialien muss von Fall zu Fall überprüft werden</b> und diese Überprüfung muss <b>bei jeder Produktaktualisierung</b> wiederholt werden. Diese Kontrolle kann zu einem Qualifizierungsverlust des Materials führen.<br>\
        "
        legend1 = "(D) Hubraummotor, (P) Planungsmotor, (S) Segeln <br>\
        (■) ISO2019-konform, (□) ISO2019 fehlgeschlagen, (-) ISO2019 & ISO2008 fehlgeschlagen<br>\
        "
      
    elif languageButton.value == "italiano":
        importantenotice = "<br>\
        <font size=4>Importante</font><br> La qualifica EN-ISO-12215:2019 dei materiali dipende fortemente dall'uso finale da parte del produttore, che deve tener conto\
        le forme precise della nave e le loro misure,\
        nonché il campo di utilizzo per il quale è dichiarato.<br>\
        <b>Questa qualifica dei materiali deve essere verificata caso per caso</b> e questa verifica deve essere ripetuta <b>ad ogni aggiornamento del prodotto</b>. Questo controllo può comportare una perdita di qualificazione del materiale.<br>\
        "
        legend1 = "(D) cilindrata motore, (P) motore di pianificazione, (S) vela <br>\
        (■) Conforme a ISO2019, (□) ISO2019 non riuscito, (-) ISO2019 e ISO2008 non riusciti<br>\
        "
        
                
    elif languageButton.value == "español":
        importantenotice = "<br>\
        <font size=4>Importante</font><br> La calificación EN-ISO-12215:2019 de los materiales depende en gran medida de su uso final por parte del fabricante, quien debe tener en cuenta\
        las formas precisas del barco y sus medidas,\
        así como el ámbito de uso para el que se declara.<br>\
        <b>Esta calificación de los materiales debe verificarse caso por caso</b> y esta verificación debe repetirse <b>en cada actualización del producto</b>. Este control puede resultar en una pérdida de calificación del material.<br>\
        "
        legend1 = "(D) desplazamiento del motor, (P) motor de planificación, (S) navegación <br>\
        (■) Cumple con ISO2019, (□) ISO2019 falló, (-) ISO2019 e ISO2008 fallaron<br>\
        "   
    
    #demonstration
    demonstration = "<font size=4>"+table.loc[index,"Reference"]+"</font><br>│"
    demonstration = demonstration + '{:>50} : {:>10}│'.format(
        "",
        table.loc[index,"Matiere"]
    )
    demonstration = demonstration + '{:>50} : {:>10}kg/m3│'.format(
        "Density ρ",
        table.loc[index,"Masse volumique ρ"]
    )
    demonstration = demonstration + '{:>10} : {:>10}│'.format(
        "Elongation at break",
        table.loc[index,"εuf1b"]
    )
    demonstration = demonstration + '{:>50} : {:>10}MPa│'.format(
        "Ultimate shear strenght",
        table.loc[index,"τ12"]
    )
    demonstration = demonstration + '{:>10} : {:>10}MPa│'.format(
        "Ultimate compressive strenght",
        table.loc[index,"σuc1"]
    )
    
    demonstrationObject = demonstration
    demonstration = demonstration + "<br><br>"
    
    resultatcontrol = control_resultat()
    
    demonstration = demonstration  + resultatcontrol + "<br><br>"
    
    demonstration = demonstration + "\
    &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; D&nbsp;&nbsp;&nbsp;&nbsp; P&nbsp;&nbsp;&nbsp;&nbsp; S&nbsp;&nbsp;&nbsp;&nbsp;<BR>\
    " 
    
    demonstration = demonstration + "\
    <font size=2>A category&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_a_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    "
    
    demonstration = demonstration + "\
    <font size=2>B category&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_b_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    "
    
    demonstration = demonstration + "\
    <font size=2>C category&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_c_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "\
    <br>\
    "
    
    demonstration = demonstration + "\
    <font size=2>D category&nbsp;&nbsp;&nbsp;&nbsp;</font>\
    "
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>d_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>p_d_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    
    if table.loc[index,"τd"]>taudcomin2008:
        
        if (table.loc[index,"σd"]>v_abcd_sigmadccomin2019/kAM) & (table.loc[index,"τd"]>taudcomin2019/kAM):
            demonstration = demonstration + " ■&nbsp;&nbsp;&nbsp;&nbsp; "
        else:
            demonstration = demonstration + " □&nbsp;&nbsp;&nbsp;&nbsp; "
    else:
        demonstration = demonstration + " -&nbsp;&nbsp;&nbsp;&nbsp; "
    demonstration = demonstration + "<br>"\
    + legend1
    
    
    demonstration = demonstration + "<br>\
    <font size=2>\
    "
    demonstration = demonstration + "\
        ▪ Minimum required shear strenght τdco,min = \
    "
    demonstration = demonstration + str('{:.2f}'.format(taudcomin2019)) + "MPa " + "<code> min(max(" + str(b) + "-" + str(a) + " x " + str(lwlButton.value) +  ", 0.3), 0.58)</code><br>"
    demonstration = demonstration + "\
        ▪ Minimum required compressive strenght σdcco,min = \
    "
    if modeleTypeButton.value =="Moteur à déplacement":
        demonstration = demonstration + str('{:.2f}'.format(d_abcd_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x (2.4 x "+ str('{:.0f}'.format(mldcButton.value))+ "^0.33+20)</code><br>"
    elif modeleTypeButton.value =="Voilier":
        demonstration = demonstration + str('{:.2f}'.format(v_abcd_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x (2.0 x "+ str('{:.0f}'.format(mldcButton.value))+ "^0.33+18)*1.0</code><br>"
    else:
        if listeDesignCategoryButton.value == "A":
            demonstration = demonstration + str('{:.2f}'.format(p_a_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+1.0 x 3.0))</code><br>"
    
        elif listeDesignCategoryButton.value == "B":
            demonstration = demonstration + str('{:.2f}'.format(p_b_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+0.8 x 3.0))</code><br>"
    
        elif listeDesignCategoryButton.value == "C":
            demonstration = demonstration + str('{:.2f}'.format(p_c_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+0.6 x 3.0))</code><br>"
    
        elif listeDesignCategoryButton.value == "D": 
             demonstration = demonstration + str('{:.2f}'.format(p_d_sigmadccomin2019))+ "MPa "  + "<code> 0.008 x PBASE = 0.008 x 0.1 x "+ str('{:.0f}'.format(mldcButton.value))+ " / " + str('{:.2f}'.format(lwlButton.value))+ " / "+ str('{:.2f}'.format(Bc))+ "x (1+0.4 x 3.0))</code><br>"

    demonstration = demonstration + "\
        ▪ Minimum required shear strenght τdco,min2008 = \
    "
    demonstration = demonstration + str('{:.2f}'.format(taudcomin2008))+ "MPa " + "<code> min(max(0.25 + 0.03 x ("+ str(lwlButton.value) +  " - 10), 0.25), 0.40)</code><br>"
    
    try:
        
        val = float(table.loc[index,"εuf1b"])
        if val <= 0.35:
            demonstration = demonstration + "\
            ▪ Design shear strenght τdco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"τd"])) + "MPa " + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.55 x 0.9 x" + str(table.loc[index,"τ12"]) + "</code>.<br> "
            demonstration = demonstration + "\
            ▪ Design compressive strenght σdcco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"σd"])) + "MPa " + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.55 x 0.9 x" + str(table.loc[index,"σuc1"]) + "</code></font>.<br> "

        elif val > 0.35:
            demonstration = demonstration + "\
            ▪ Design shear strenght τdco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"τd"])) + "MPa " + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.65 x 0.9 x" + str(table.loc[index,"τ12"]) + "</code>.<br> "
            demonstration = demonstration + "\
            ▪ Design compressive strenght σdcco = \
            "
            demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"σd"])) + "MPa " + "<code>  " + str(table.loc[index,"εuf1b"]) + "<0.35 " + str(float(table.loc[index,"εuf1b"])<0.35) + ", 0.65 x 0.9 x" + str(table.loc[index,"σuc1"]) + "</code></font>.<br> "
    except ValueError:
        demonstration = demonstration + "\
        ▪ Design shear strenght plan τdco = \
        "
        demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"τd"])) + "MPa " + "<code>  " + "balsa core " + str(True) + ", 0.50 x 0.9 x" + str(table.loc[index,"τ12"]) + "</code>.<br> "
        demonstration = demonstration + "\
        ▪ Design compressive strenght σdcco = \
        "
        demonstration = demonstration + str('{:.2f}'.format(table.loc[index,"σd"])) + "MPa " + "<code>  " + "balsa core " + str(True) + ", 0.50 x 0.9 x" + str(table.loc[index,"σuc1"]) + "</code></font>.<br> "
   
    
    demonstration = demonstration + importantenotice
    
    return demonstration, demonstrationObject

# %%
#init
a = -0.07
b = -0.12
taudcomin2019,taudcomin2008,d_abcd_sigmadccomin2019,p_a_sigmadccomin2019,p_b_sigmadccomin2019,p_c_sigmadccomin2019,p_d_sigmadccomin2019,v_abcd_sigmadccomin2019,kAM,ksls,kdyn,Bc,V = tableA7_requirements(methodeButton.value,lwlButton.value,mldcButton.value)
#print(taudcomin2019,taudcomin2008,d_abcd_sigmadccomin2019,kAM)
table["τd"]=[""]*27
table["σd"]=[""]*27
for i in range(len(table)):
    try:
        val = float(table.loc[i,"εuf1b"])
        if val <= 0.35:
            table.loc[i,"τd"]=float(table.loc[i,"τ12"])*0.55*0.9
            table.loc[i,"σd"]=float(table.loc[i,"σuc1"])*0.55*0.9
        elif val > 0.35:
            table.loc[i,"τd"]=float(table.loc[i,"τ12"])*0.65*0.9
            table.loc[i,"σd"]=float(table.loc[i,"σuc1"])*0.65*0.9
    except ValueError:
        table.loc[i,"τd"]=float(table.loc[i,"τ12"])*0.50*0.9
        table.loc[i,"σd"]=float(table.loc[i,"σuc1"])*0.50*0.9
        
valid2019 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']>d_abcd_sigmadccomin2019/kAM),"Reference"].tolist()
newunvalid1 = table.loc[(table['τd']>taudcomin2008) & (table['τd']<=taudcomin2019/kAM),"Reference"].tolist()
newunvalid2 = table.loc[(table['τd']>taudcomin2019/kAM) & (table['σd']<=d_abcd_sigmadccomin2019/kAM),"Reference"].tolist()
newunvalid = newunvalid1 + newunvalid2

shorted = ""
for i in valid2019:
    shorted = shorted + ", " + i


excluded = ""
for i in newunvalid:
    excluded = excluded + ", " + i

    
    
g=widgets.HTML("")
h=widgets.HTML("")
f=widgets.HTML("")
details = widgets.HTML("")
previewReport = HBox([details,g],layout= general_layout)
previewcertificate = HBox([f],layout = general_layout)

# %%
file = open("service1.PNG", "rb")
image = file.read()
service1 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

file = open("service2.PNG", "rb")
image = file.read()
service2 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

file = open("service3.PNG", "rb")
image = file.read()
service3 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

file = open("service4.PNG", "rb")
image = file.read()
service4 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

#head_display = HBox([menu2],layout = head_display_layout )
up=HBox([service1,service2],layout=center_layout)
down=HBox([service3,service4],layout=center_layout)
VBox([up,down],layout=center_layout)

# %%
widgets.HTML(
            value="<br>",
            placeholder='',
            description='',
)
# Out:
# HTML(value='<br>', placeholder='')

# %%
widgets.HBox([languageButton],layout=center_layout)

# %%
def change_language(change):

    if languageButton.value == "français":
        text = "Plate-forme d'Application"
        paragrapheSection2.value="<font size=4><b>Au service des concepteurs, constructeurs, administrations et utilisateurs de bateaux de plaisance de moins de 24 mètres.\
        </b></font>\
        Un outil indispensable qui permet à chacun d'obtenir et de partager des contrôles certifiés avec \
        le plus haut niveau de sécurité et de confidentialité.<br>\
        \
        "
        submitterNameButton.description = "Nom(*)"
        submitterFirstNameButton.description = "Prénom"
        submitterAdress.description = "Adresse(*)"
        submitterTown.description = "Ville(*)"
        submitterPost.description = "Code postal(*)"
        submitterCountry.description ="Pays(*)"
        
        uniteButton.description = "Nom du bateau(**)"
        modeleButton.description = "Modèle"
        WINBUTTON.description = "Numéro d'identification de coque(**)"
        architecteButton.description ="Architecte"
        listeDesignCategoryButton.description = "Catégorie de conception(*)"
        lwlButton.description = "Longueur de flottaison(*)"
        mldcButton.description = "Déplacement total en charge(*)"
        
        Title11.value = "<font size=4><b>DEMANDEUR </b> \
        </font></font><br>"
        Title12.value = "<font size=2>\
        Pour votre information, veuillez lire nos conditions d'utilisation dans ce document.\
        Tous les champs obligatoires doivent être correctement remplis. Le contenu de votre formulaire ne peut pas être enregistré.\
        <b>Sauf si tous les champs obligatoires ont été remplis, votre formulaire n'est pas valide pour soumission.</b>\
        <b>La demande de contrôle n'est autorisée qu'après votre confirmation des informations fournies. S'il vous plaît, \
        assurez-vous que les informations fournies sont correctes, car toute fausse déclaration sera poursuivie.</b>"
        Title13.value="<font size=2>\
        Une adresse email valide est requise. Vérifiez bien votre catégorie de demandeur dans le menu déroulant, à droite.\
        Lorsque tous les champs obligatoires sont remplis, utilisez le bouton de validation pour soumettre les informations renseignées. \
        "
        
        Title21.value="<font size=4><b>PRODUIT</b> </font></font><br>"
        Title22.value="<font size=2>\
        Utilisez le bouton à droite pour remplir automatiquement à partir d'un fichier ISCANT. \
        Lorsque tous les champs obligatoires sont remplis, utilisez le bouton de validation pour soumettre les informations renseignées. \
        "
        
        Title411.value = "<font size=6><b>Contrôle Certifié des Bateaux de Plaisance de moins de 24 mètres\
        </b> </font>"
        Title412.value = "\
        La procédure disponible actuellement est \
        <b>Exigences minimales pour la résistance du matériau de base\
        <u>-Minimum requirements for core material strenght-</u></i></b>. Pour des questions techniques liées à la procédure de contrôle, ou,\
        si nous n'avons pas encore votre matériau d'âme dans notre base de donnée, merci d'envoyer un mail à l'adresse suivante : contact@ace-nautic.fr.<br>\
        L'autorité de contrôle est représentée par A.C.E. CATTELLIOT INGÉNIERIE, 23 RUE LAVOISIER 17 440 AYTRE, FRANCE, \
        habilité par l'organisme notifié ENAVE, VIA MARIO MOROSI, 16, 61032 Fano PU, ITALIE \
        "
        Title41.value = "<font size=4><b>CONTRÔLE</b> </font></font><br>" 
        Title456.value = "DESCRIPTION"
        Title500.value = "DOCUMENTATION TECHNIQUE"
        
        submitname3.value = "<font size=2>LE DEMANDEUR </font><font size=2><b><u>"\
        + submitterNameButton.value\
        + "</u></b></font>\
        <font size=2> fait appel à l'AUTORITE DE CONTRÔLE </font><font size=2><b><u> \
        A.C.E CATTELLIOT INGÉNIERIE\
        </u></b></font>\
        <font size=2> pour évaluer le matériau de d'âme désigné </font><font size=2><b><u>"\
        + matiereButton.value \
        + "</u></b></font>\
        <font size=2> concernant la conformité du PRODUIT </font><font size=2><b><u>"\
        + modeleButton.value \
        + "</u></b></font>\
        <font size=2> avec le RÈGLEMENT </font><font size=2><b><u>"\
        + contextButton.value \
        + "</u></b></font><font size=2> suivant la PROCEDURE d'évaluation </font><font size=2><b><u>" \
        + controlButton.value \
        + "</u></b></font>." 
        
        Title77.value ="\
        <b>Les résultats affichés ne sont pas des résultats <u>certifiés</u>. Les informations extraites de cette page \
        n'ont aucune valeur légale et ne doivent pas être employés à quelque fin que ce soit. Par conséquent, ni l'AUTORITÉ DE CONTRÔLE \
        A.C.E. CATTELLIOT ENGINEERING, ni l'organisme notifié ENAVE ne saurait être responsable de l'exploitation des informations affichées.</b>\
        Les résultats certifiés sont envoyés par email au DEMANDEUR et à l'AUTORITE DE CONTROLE. Pour plus de détails, merci d'envoyer un mail à l'adresse suivante : contact@ace-nautic.fr" 
 

        Title31.value = "<font size=4><b>RAPPORT DÉTAILLÉ</b></font></font><br>"
        Title51.value = "<font size=4><b>CERTIFICAT DE CONTRÔLE</b> (prévisualisation)</font></font><br>"
        

    elif languageButton.value == "english":
        text = "Application Platform"
        paragrapheSection2.value="<font size=4><b>Delivering service \
        to designers, builders, administrations, and users of recreational crafts under 24 meters.</b> </font>\
        An essential tool that allows everyone to obtain and share certified controls with \
        the highest level of security and privacy.<br>\
        "
        submitterNameButton.description = "Name(*)"
        submitterFirstNameButton.description = "First Name"
        submitterAdress.description = "Address(*)"
        submitterTown.description = "City(*)"
        submitterPost.description = "Postal code(*)"
        submitterCountry.description ="Country(*)"
        
        uniteButton.description = "Name of the Boat(**)"
        modeleButton.description = "Model"
        WINBUTTON.description = "Watercraft Identification Number(**)"
        architecteButton.description ="Architect"
        listeDesignCategoryButton.description = "Design Category(*)"
        lwlButton.description = "Length of Waterline(*)"
        mldcButton.description = "Total Displacement In Maximum Loading Condition(*)" 
        
        Title11.value = "<font size=4><b>APPLICANT </b> \
        </font></font><br>"
        Title12.value = "<font size=2>\
        For your information, please read our terms of service in this document.\
        All required fields should be correctly completed. The content of your form cannot be saved. \
        <b>Unless all mandatory fields have been filled, your form is not valid for submission.</b>\
        <b>The control request is only be allowed after your confirmation of the given informations. Please, \
        make sure that the given informations are correct, as any false declaration will be prosecuted.</b>"
        
        Title13.value="<font size=2>\
        A valid email address is required. Be sure to check your applicant category in the drop-down menu on the right. \
        When all the mandatory fields are filled, use the validation button to submitt the given informations. \
        "
        
        Title21.value="<font size=4><b>PRODUCT</b> </font></font><br>"
        Title22.value="<font size=2>\
        Use the button on the right to automatically fill from ISCANT file. \
        When all the mandatory fields are filled, use the validation button to submitt the given informations on the product. \
        "
        
        
        Title411.value = "<font size=6><b>Certified Control of Recreationnal Crafts under 24 meters\
        </b> </font>"
        Title412.value = "\
        The procedure available at the moment is\
        <b>Minimum requirements for core material strenght</b>. For technical questions related to the control procedure, or,\
        if we haven't yet your material in our database, please, send an email to the following address : contact@ace-nautic.fr.<br>\
        The control autority is represented by A.C.E. CATTELLIOT ENGINEERING,23 RUE LAVOISIER 17 440 AYTRE, FRANCE,  \
        under the agreement of the notified body ENAVE, VIA MARIO MOROSI, 16, 61032 Fano PU, ITALY \
        "
        Title41.value = "<font size=4><b>CONTROL</b> </font></font><br>"
        Title456.value = "DESCRIPTION"
        Title500.value = "TECHNICAL DOCUMENTATION"
        
        submitname3.value = "<font size=2>The APPLICANT </font><font size=2><b><u>"\
        + submitterNameButton.value\
        + "</u></b></font>\
        <font size=2> calls upon the CONTROL AUTHORITY </font><font size=2><b><u> \
        A.C.E CATTELLIOT ENGINEERING\
        </u></b></font>\
        <font size=2> to evaluate the designated core material </font><font size=2><b><u>"\
        + matiereButton.value \
        + "</u></b></font>\
        <font size=2> regarding the compliancy of the PRODUCT </font><font size=2><b><u>"\
        + modeleButton.value \
        + "</u></b></font>\
        <font size=2> with the REGULATION </font><font size=2><b><u>"\
        + contextButton.value \
        + "</u></b></font><font size=2> following the PROCEDURE of evaluation </font><font size=2><b><u>" \
        + controlButton.value \
        + "</u></b></font>." 
        
        Title77.value = "\
        <b>The displayed RESULTS are not certified RESULTS. The informations taken out of this page \
        have no legal values and should not be employed for any purpose. Therefore, nor the CONTROL AUTHORITY \
        A.C.E. CATTELLIOT ENGINEERING, nor the notified body ENAVE should be responsible of any employement of the informations displayed.</b>\
        Certified results are sent by email at the APPLICANT and at the CONTROL AUTORITHY. For more details, please, send an email to the following adress : contact@ace-nautic.fr"
        
        Title31.value = "<font size=4><b>DETAILED REPORT</b></font></font><br>"
        Title51.value = "<font size=4><b>CERTIFICATE OF CONTROL</b> (preview)</font></font><br>" 
        
    elif languageButton.value == "deutsch":
        text = "Applikationsplattform"
        paragrapheSection2.value="<font size=4><b>Lieferservice für Designer, Bauherren, Verwaltungen und Benutzer von Sportbooten unter 24 Metern.\
        </b></font>\
        Ein unverzichtbares Tool, mit dem jeder zertifizierte Kontrollen erhalten und teilen kann \
        mit der höchste Maß an Sicherheit und Datenschutz.<br>\
        "
        submitterNameButton.description= "Name(*)"
        submitterFirstNameButton.description = "Vorname"
        submitterAdress.description = "Anschrif(*)"
        submitterTown.description = "stadt(*)"
        submitterPost.description = "Postleizahl(*)"
        submitterCountry.description ="Land(*)"
        
        uniteButton.description = "Name des Bootes(**)"
        modeleButton.description = "Modell"
        WINBUTTON.description = "Sportbootidentifikationsnummer(**)"
        architecteButton.description ="Architekt"
        listeDesignCategoryButton.description = "Design-Kategorie(*)"
        lwlButton.description = "Wasserlinienlänge(*)"
        mldcButton.description = "maximal belastete Verdrängung(*)" 
        
        
        Title11.value = "<font size=4><b>ANTRAGSTELLER(ERIN) </b> \
        </font></font><br>"
        Title12.value = "<font size=2>\
        Bitte lesen Sie zu Ihrer Information unsere Nutzungsbedingungen in diesem Dokument.\
        Alle Pflichtfelder sollten korrekt ausgefüllt sein. Der Inhalt Ihres Formulars kann nicht gespeichert werden.\
        <b>Wenn nicht alle Pflichtfelder ausgefüllt wurden, kann Ihr Formular nicht eingereicht werden.</b>\
        <b>Die Kontrollanfrage wird nur nach Ihrer Bestätigung der gemachten Angaben zugelassen. Bitte, \
        ergewissern Sie sich, dass die angegebenen Informationen korrekt sind, da jede falsche Angabe strafrechtlich verfolgt wird. </b>"
        Title13.value="<font size=2>\
        Eine gültige E-Mail-Adresse wird benötigt. Überprüfen Sie unbedingt Ihre Bewerberkategorie im Drop-down-Menü auf der rechten Seite. \
        Wenn alle Pflichtfelder ausgefüllt sind, verwenden Sie die Bestätigungsschaltfläche, um die angegebenen Informationen zu übermitteln. \
        "

        Title21.value="<font size=4><b>PRODUCKT</b> </font></font><br>"
        Title22.value="<font size=2>\
        Verwenden Sie die Schaltfläche auf der rechten Seite, um automatisch aus der ISCANT-Datei auszufüllen.\
        Wenn alle Pflichtfelder ausgefüllt sind, verwenden Sie die Bestätigungsschaltfläche, um die angegebenen Informationen zu übermitteln."

        Title411.value = "<font size=6><b>Zertifizierte Kontrolle von Sportbooten unter 24 Metern\
        </b> </font>"
        Title412.value = "\
        Das derzeit verfügbare Verfahren ist\
        <b>Mindestanforderungen an die Festigkeit des Kernmaterials\
        <u>-Minimum requirements for core material strenght-</u></i></b>. Bei technischen Fragen zum Kontrollverfahren, oder\
        Wenn wir Ihr Material noch nicht in unserer Datenbank haben, senden Sie bitte eine E-Mail an die folgende Adresse: contact@ace-nautic.fr.<br>\
        Die Kontrollbehörde wird vertreten durch A.C.E. CATTELIOT ENGINEERING, 23 RUE LAVOISIER 17 440 AYTRE, FRANKREICH, \
        mit Zustimmung der benannten Stelle ENAVE, VIA MARIO MOROSI, 16, 61032 Fano PU, ITALIEN \
        "
        Title41.value = "<font size=4><b>KONTROLLE</b> </font></font><br>"
        Title456.value = "BESCHREIBUNG"
        Title500.value = "TECHNISCHE DOKUMENTATION" 
        
        submitname3.value = "<font size=2>Der(Die) ANTRAGSTELLER(ERIN) </font><font size=2><b><u>"\
        + submitterNameButton.value\
        + "</u></b></font>\
        <font size=2> wendet sich an die KONTROLLBEHÖRDE </font><font size=2><b><u> \
        A.C.E. CATTELIOT ENGINEERING\
        </u></b></font>\
        <font size=2> zur Bewertung des vorgesehenen Kernmaterials </font><font size=2><b><u>"\
        + matiereButton.value \
        + "</u></b></font>\
        <font size=2> bezüglich der Konformität des PRODUKTS </font><font size=2><b><u>"\
        + modeleButton.value \
        + "</u></b></font>\
        <font size=2> mit der VERORDNUNG </font><font size=2><b><u>"\
        + contextButton.value\
        + "</u></b></font><font size=2> nach dem Bewertungsverfahren </font><font size=2><b><u>" \
        + controlButton.value\
        + "</u></b></font>." 
        
        Title77.value ="\
        <b>Die angezeigten ERGEBNISSE sind keine zertifizierten ERGEBNISSE. Die dieser Seite entnommenen Informationen \
        haben keinen rechtlichen Wert und sollten für keinen Zweck verwendet werden. Daher noch die KONTROLLBEHÖRDE \
        A.C.E. CATTELLIOT ENGINEERING, noch die benannte Stelle ENAVE sind für die Verwendung der angezeigten Informationen verantwortlich.</b>\
        Zertifizierte Ergebnisse werden per E-Mail an den ANTRAGSTELLER und an die KONTROLLAUTORITÄT gesendet. Für weitere Einzelheiten senden Sie bitte eine E-Mail an die folgende Adresse: contact@ace-nautic.fr" 
        
        Title31.value = "<font size=4><b>DETAILLIERTER BERICHT</b></font></font><br>"
        Title51.value = "<font size=4><b>KONTROLLZERTIFIKAT</b> (Vorschau)</font></font><br>" 

        
    elif languageButton.value == "italiano":
        text ="Modulo di Applicazione"
        paragrapheSection2.value="<font size=4><b>Servizio di consegna per progettisti, costruttori, amministrazioni e utilizzatori di imbarcazioni da diporto sotto i 24 metri.\
        </b></font>\
        Uno strumento essenziale che permette a chiunque di ottenere e condividere controlli certificati con il massimo livello di sicurezza e privacy.<br>\
        "
        submitterNameButton.description = "Nome della ditta,Cognome(*)"
        submitterFirstNameButton.description = "Nome"
        submitterAdress.description = "Indirizzo(*)"
        submitterTown.description = "Città(*)"
        submitterPost.description = "Codice postale(*)"
        submitterCountry.description ="Nazione(*)"
        
        uniteButton.description = "Nome della barca(**)"
        modeleButton.description = "Modello"
        WINBUTTON.description = "Numero di Identificazione dell'unitá (WIN)**)"
        architecteButton.description ="Architetto"
        listeDesignCategoryButton.description = "Categoria(*)"
        lwlButton.description = "Lunghezza della linea di galleggiamento(*)"
        mldcButton.description = "Spostamento totale sotto carico(*)" 
        
        Title11.value = "<font size=4><b>RICHIEDENTE </b> \
        </font></font><br>"
        Title12.value = "<font size=2>\
        Per vostra informazione, leggi i nostri termini di utilizzo in questo documento.\
        Tutti i campi obbligatori devono essere compilati correttamente. Il contenuto del tuo modulo non può essere salvato.\
        <b>Se tutti i campi obbligatori non sono compilati, il tuo modulo non può essere inviato.</b>\
        <b>La richiesta di controllo è consentita solo dopo la tua conferma delle informazioni fornite. Per favore, \
        Assicurarsi che le informazioni fornite siano corrette, in quanto ogni falsa dichiarazione sarà perseguita. </b>"
        Title13.value="<font size=2>\
        È necessario un indirizzo email valido. Assicurati di controllare la categoria del candidato nel menu a discesa a destra.\
        Quando tutti i campi obbligatori sono stati compilati, utilizzare il pulsante di convalida per inviare le informazioni fornite. \
        "

        Title21.value="<font size=4><b>PRODOTTO</b> </font></font><br>"
        Title22.value="<font size=2>\
        Utilizzare il pulsante a destra per compilare automaticamente dal file ISCANT.\
        Quando tutti i campi obbligatori sono stati compilati, utilizzare il pulsante di convalida per inviare le informazioni fornite."

        Title411.value = "<font size=6><b>Controllo Certificato Delle Imbarcazioni Ricreative sotto i 24 metri\
        </b> </font>"
        Title412.value = "\
        La procedura disponibile al momento è\
        <b>Requisiti minimi per la resistenza del materiale dell'anima\
        <u>-Minimum requirements for core material strenght-</u></i></b>. Per domande tecniche relative alla procedura di controllo, oppure,\
        se non abbiamo ancora il tuo materiale nel nostro database, invia un'e-mail al seguente indirizzo: contact@ace-nautic.fr.<br>\
        L'autorità di controllo è rappresentata da A.C.E. CATTELLIOT ENGINEERING,23 RUE LAVOISIER 17 440 AYTRE, FRANCIA, \
        con il consenso dell'organismo notificato ENAVE, VIA MARIO MOROSI, 16, 61032 Fano PU, ITALY \
        "
        Title41.value = "<font size=4><b>CONTROLLO</b> </font></font><br>"
        Title456.value = "DESCRIZIONE"
        Title500.value = "DOCUMENTAZIONE TECNICA" 
        
        submitname3.value = "<font size=2>Il RICHIEDENTE </font><font size=2><b><u>"\
        + submitterNameButton.value\
        + "</u></b></font>\
        <font size=2> chiama l'AUTORITÀ DI CONTROLLO </font><font size=2><b><u> \
        INGEGNERIA A.C.E CATTELLIOT\
        </u></b></font>\
        <font size=2> per valutare il materiale del nucleo designato </font><font size=2><b><u>"\
        + matiereButton.value\
        + "</u></b></font>\
        <font size=2> in merito alla conformità del PRODOTTO </font><font size=2><b><u>"\
        + modeleButton.value\
        + "</u></b></font>\
        <font size=2> con il REGOLAMENTO </font><font size=2><b><u>"\
        + contextButton.value\
        + "</u></b></font><font size=2> seguendo la PROCEDURA di valutazione </font><font size=2><b><u>" \
        + controlButton.value\
        + "</u></b></font>." 
        
        Title77.value = "<b>I RISULTATI mostrati non sono RISULTATI certificati. Le informazioni estratte da questa pagina \
         non hanno valore legale e non devono essere utilizzati per alcuno scopo. Pertanto, né l'AUTORITÀ DI CONTROLLO \
         ASSO. CATTELLIOT ENGINEERING, né l'organismo notificato ENAVE dovrebbero essere responsabili dell'uso fatto delle informazioni visualizzate.</b>\
         Gli esiti certificati vengono inviati tramite posta elettronica al RICHIEDENTE e all'AUTORITÀ DI CONTROLLO. Per maggiori dettagli, inviare una e-mail al seguente indirizzo: contact@ace-nautic.fr"        
        
        Title31.value = "<font size=4><b>RAPPORTO DETTAGLIATO</b></font></font><br>"
        Title51.value = "<font size=4><b>CERTIFICATO DI CONTROLLO</b> (anteprima)</font></font><br>" 
        
    elif languageButton.value == "español":
        text = "Plataforma de Aplicación"
        paragrapheSection2.value="<font size=4><b>Servicio de entrega para diseñadores, constructores, administraciones y usuarios de embarcaciones de recreo de menos de 24 metros.\
        </b></font>\
        Una herramienta esencial que permite a cualquier persona obtener y compartir cheques certificados con el más alto nivel de seguridad y privacidad.<br>\
        "
        submitterNameButton.description= "Nombre,nombre de la empresa(*)"
        submitterFirstNameButton.description = "Apellido"
        submitterAdress.description = "Dirección(*)"
        submitterTown.description = "Ciudad(*)"
        submitterPost.description = "Código postal(*)"
        submitterCountry.description ="País(*)"
        
        uniteButton.description = "Nombre del barco(**)"
        modeleButton.description = "Modelo"
        WINBUTTON.description = "Número de Identificación de la embarcación(**)"
        architecteButton.description ="Arquitecto"
        listeDesignCategoryButton.description = "Categoría(*)"
        lwlButton.description = "Longitud de la línea de flotación(*)"
        mldcButton.description = "Desplazamiento total bajo carga(*)" 
        
        Title11.value = "<font size=4><b>SOLICITANTE </b> \
        </font></font><br>"
        Title12.value = "<font size=2>\
        Para su información, lea nuestros términos de uso en este documento.\
        Todos los campos obligatorios deben ser llenados correctamente. El contenido de su formulario no se puede guardar.\
        <b>Si no se completan todos los campos obligatorios, su formulario no se puede enviar.</b>\
        <b>La solicitud de control solo se permite después de su confirmación de la información proporcionada. Por favor, \
        asegúrese de que la información proporcionada sea correcta, ya que cualquier declaración falsa será procesada. </b>"
        Title13.value="<font size=2>\
        Se requiere una dirección de correo electrónico válida. Asegúrese de verificar su categoría de solicitante en el menú desplegable a la derecha.\
        Cuando todos los campos obligatorios estén llenos, use el botón de validación enviar la información proporcionada. \
        "

        Title21.value="<font size=4><b>PRODUCTO</b> </font></font><br>"
        Title22.value="<font size=2>\
        Use el botón de la derecha para llenar automáticamente desde el archivo ISCANT.\
        Cuando todos los campos obligatorios estén completos, utilice el botón de validación para enviar la información proporcionada sobre el producto."
        Title411.value = "<font size=6><b>Control Certificado de Embarcaciones de Recreo de menos de 24 metros\
        </b> </font>"
        Title412.value = "\
        El procedimiento disponible en este momento es\
        <b>Requisitos mínimos de resistencia del material del núcleo\
        <u>-Minimum requirements for core material strenght-</u></i></b>. Para preguntas técnicas relacionadas con el procedimiento de control, o,\
        si aún no tenemos su material en nuestra base de datos, envíe un correo electrónico a la siguiente dirección: contact@ace-nautic.fr.<br>\
        La autoridad de control está representada por A.C.E. INGENIERÍA CATTELLIOT, 23 RUE LAVOISIER 17 440 AYTRE, FRANCIA, \
        con el acuerdo del organismo notificado ENAVE, VIA MARIO MOROSI, 16, 61032 Fano PU, ITALIA \
        "
        Title41.value = "<font size=4><b>CONTROL</b> </font></font><br>"
        Title456.value = "DESCRIPCIÓN"
        Title500.value = "DOCUMENTACIÓN TÉCNICA" 
        
        submitname3.value = "<font size=2>El SOLICITANTE </font><font size=2><b><u>"\
        + matiereButton.value\
        + "</u></b></fuente>\
        <font size=2> hace un llamado a la AUTORIDAD DE CONTROL </font><font size=2><b><u> \
        INGENIERÍA A.C.E CATTELLIOT\
        </u></b></fuente>\
        <font size=2> para evaluar el material central designado </font><font size=2><b><u>"\
        + matiereButton.value\
        + "</u></b></fuente>\
        <font size=2> con respecto a la conformidad del PRODUCTO </font><font size=2><b><u>"\
        + modeleButton.value\
        + "</u></b></fuente>\
        <font size=2> con el REGLAMENTO </font><font size=2><b><u>"\
        + contextButton.value\
        + "</u></b></font><font size=2> siguiendo el PROCEDIMIENTO de evaluación </font><font size=2><b><u>" \
        + controlButton.value\
        + "</u></b></font>" 
        
        Title77.value = "<b>Los RESULTADOS mostrados no son RESULTADOS certificados. Las informaciones extraídas de esta página \
        no tienen valores legales y no deben ser empleados para ningún propósito. Por tanto, ni la AUTORIDAD DE CONTROL \
        A.C.E. CATTELLIOT ENGINEERING, ni el organismo notificado ENAVE deben ser responsables del uso que se haga de la información mostrada.</b>\
        Los resultados certificados se envían por correo electrónico al SOLICITANTE ya la AUTORIDAD DE CONTROL. Para más detalles, envíe un correo electrónico a la siguiente dirección: contact@ace-nautic.fr"
        
        Title31.value = "<font size=4><b>INFORME DETALLADO</b></font></font><br>"
        Title51.value = "<font size=4><b>CERTIFICADO DE CONTROL</b> (vista previa)</font></font><br>" 
        
    Section2.value = "<font size=6><b></b>"\
    + text\
    + "</font></b><br>\
    <font size=3>STANDARD PRODUCT QUALITY CONTROL</font><br><br><br>"
    
    
    if languageButton.value == 'english':

        legend1 = "(D) Displacement motorcraft, (P) Planning motorcraft, (S) sailing craft"
        
    elif languageButton.value == 'français':

        legend1 = "(D) Bateau à moteur à déplacement, (P) Bateau à moteur planant, (V) Voilier"
              
    elif languageButton.value == "deutsch":
 
        legend1 = "(D) Hubraummotor, (P) Planungsmotor, (S) Segeln"
      
    elif languageButton.value == "italiano":

        legend1 = "(D) Cilindrata Motore, (P) Motore di Pianificazione, (S) Vela"
        
                
    elif languageButton.value == "español":

        legend1 = "(D) desplazamiento del motor, (P) motor de planificación, (S) navegación"   
    Title22.value = Title22.value + "&nbsp;&nbsp;" + legend1

# %%
Section2 = widgets.HTML(
            value="<font size=6><b></b>"\
            + ""
            + "</font></b><br>\
            <font size=3>STANDARD PRODUCT QUALITY CONTROL</font><br><br><br>",
            placeholder='',
            description='',
)    
    
HBox([Section2],layout= center_layout)

# %%
 #Each application is identified by a unique submit number. This submit number is a private key\
#that contains all the informations of your application and the detail of your request,\
#including date and time, except the detailed report.\
#<b>The submit number certify the quality control. If lost, please, apply again.<br></b>


paragrapheSection2 = widgets.HTML(
        value="<font size=4><b>Delivering service \
        to designers, builders, administrations, and users of recreational crafts under 24 meters.</b> </font>\
        An essential tool that allows everyone to get and share certified controls with \
        the highest level of security and privacy.<br>\
        For your information, please read our terms of service in this document.\
        ",
        placeholder='',
        description='',
    
)

paragrapheSection2
# Out:
# HTML(value='<font size=4><b>Delivering service        to designers, builders, administrations, and users of re…

# %%
Title12 = widgets.HTML(
            value="<font size=2>\
            All required fields should be correctly completed. The content of your form cannot be saved. \
            <b>Unless all mandatory fields have been filled, your form is not valid for submission.</b>",
            placeholder='',
            description='',
)

Title12
# Out:
# HTML(value='<font size=2>            All required fields should be correctly completed. The content of your fo…

# %%
widgets.HTML(
            value="<br><hr>",
            placeholder='',
            description='',
)
# Out:
# HTML(value='<br><hr>', placeholder='')

# %%
file = open("icone1.PNG", "rb")
image = file.read()
icone1 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

#head_display = HBox([menu2],layout = head_display_layout )
HBox([icone1],layout=center_layout)

# %%
Title11 = widgets.HTML(
            value="<font size=4><b>SUBMITTER </b> Identification form\
            </font></font><br>",
            placeholder='',
            description='',
)

Title13 = widgets.HTML(
            value="<font size=2>\
            When all the mandatory fields are filled, use the validation button to confirm the given informations. \
            <b>The control request is only be allowed after your confirmation of the given informations. Please, \
            make sure that the given informations are correct, as any false declaration will be prosecuted </b>",
            placeholder='',
            description='',
)

Title1 = widgets.HBox([Title11,submitterTypeButton],layout= head_display_layout)
widgets.HBox([Title1,Title13,submitterForm],layout= form_layout640)

# %%
HBox([confirmSubmitterButton ],layout=center_layout)

# %%
widgets.HTML(
            value="<br><hr>",
            placeholder='',
            description='',
)
# Out:
# HTML(value='<br><hr>', placeholder='')

# %%
file = open("icone2.PNG", "rb")
image = file.read()
icone2 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

#head_display = HBox([menu2],layout = head_display_layout )
HBox([icone2],layout=center_layout)

# %%
Title21 = widgets.HTML(
        value="<font size=4><b>PRODUCT</b><font size=2> Identification</font></font><br>",
        placeholder='',
        description='',
)


Title22 = widgets.HTML(
            value="<font size=2>\
            Use the button on the right to automatically fill from ISCANT file. \
            When all the mandatory fields are filled, use the validation button to submitt the given informations on the product. \
            <b>The control request is only be allowed after your confirmation of the given informations. Please, \
            make sure that the given informations are correct, as any false declaration will be prosecuted </b>",
            placeholder='',
            description='',
)

Title2 = widgets.HBox([Title21,modeleTypeButton,uploader],layout= head_display_layout)
widgets.HBox([Title2,Title22,productForm],layout= form_layout640)

# %%
HBox([confirmProductButton ],layout=center_layout)

# %%
widgets.HTML(
            value="<br><hr>",
            placeholder='',
            description='',
)
# Out:
# HTML(value='<br><hr>', placeholder='')

# %%
file = open("icone6.PNG", "rb")
image = file.read()
icone6 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

#head_display = HBox([menu2],layout = head_display_layout )
HBox([icone6],layout=center_layout)

# %%
Title411 = widgets.HTML(
        value="<font size=6><b>Certified Control of Recreationnal Crafts under 24 meters\
        </b> </font>",
        placeholder='',
        description='',
)
HBox([Title411],layout=center_layout)

# %%
Title412 = widgets.HTML(
        value="\
        For technical questions related to the use of this form, please,\
        send an email to the following address : contact@ace-nautic.fr.<br>\
        The control autority is represented by A.C.E. CATTELLIOT ENGINEERING,23 RUE LAVOISIER 17 440 AYTRE, FRANCE,  \
        empowerment by the notified body ENAVE, VIA MARIO MOROSI, 16, 61032 Fano PU, ITALY \
        ",
        placeholder='',
        description='',
)

# %%
Title41 = widgets.HTML(
        value="<font size=4><b>CONTROL</b> </font></font><br>",
        placeholder='',
        description='',
)



Title4 = widgets.HBox([Title41],layout= head_display_layout)
widgets.HBox([Title4,Title412,controlForm1],layout= form_layoutboxedsmall)

# %%
file = open("icone3.PNG", "rb")
nocontractIcone = file.read()

file = open("icone4.PNG", "rb")
contractIcone = file.read()

contractZone = widgets.Image(
    value=nocontractIcone ,
    format='png',
    width=180,
    height=105,
)
contract = widgets.HBox([contractZone,controlForm4],layout=general_layout)

# %%
widgets.HBox([Title456,controlForm2,Title500,controlForm3],layout= form_layoutboxedsmall)

# %%
contract

# %%
HBox([confirmContractButton],layout=center_layout)

# %%
widgets.HTML(
            value="<br><hr>",
            placeholder='',
            description='',
)
# Out:
# HTML(value='<br><hr>', placeholder='')

# %%
file = open("icone5.PNG", "rb")
image = file.read()
icone5 = widgets.Image(
    value=image,
    format='png',
    width=180,
    height=105,
)

#head_display = HBox([menu2],layout = head_display_layout )
HBox([icone5],layout=center_layout)

# %%
Title77 =widgets.HTML(
        value="\
        <b>The displayed RESULTS are not certified RESULTS. The informations taken out of this page \
        have no legal values and should not be employed for any purpose. Therefore, nor the CONTROL AUTHORITY \
        A.C.E. CATTELLIOT ENGINEERING, nor the notified body ENAVE should be responsible of any employement of the informations displayed.</b>\
        Certified results are sent by email at the APPLICANT and at the CONTROL AUTORITHY. For more details, please, send an email to the following adress : contact@ace-nautic.fr",
        placeholder='',
        description='',
)
Title77
# Out:
# HTML(value='        <b>The displayed RESULTS are not certified RESULTS. The informations taken out of this pag…

# %%
Title31 = widgets.HTML(
        value="<font size=4><b>RESULTS</b> Detailed report </font></font><br>",
        placeholder ='',
        description='',
)
Title3 = widgets.HBox([Title31,menu3],layout= head_display_layout)
#widgets.HBox([Title3,details],layout=form_layout)
widgets.HBox([Title3,previewReport],layout=form_layout)

# %%
Title51 = widgets.HTML(
        value="<font size=4><b>CONTROL CERTIFICATE</b> (preview) </font></font><br>",
        placeholder ='',
        description='',
)
Title5 = widgets.HBox([Title51],layout= head_display_layout)
widgets.HBox([Title5,previewcertificate],layout=form_layout)

# %%
fig = px.scatter(table,
                 x="σd",
                 y="τd", 
                 color="Matiere",
                 text="Reference",
                 #size="Masse volumique ρ",
                 hover_name="Reference",
                 hover_data = ["Masse volumique ρ"])

fig.update_layout(
    title="Standard design properties of core materials",
    height = 800,
    font=dict(
        family="Arial",
        size=10,
        #color="RebeccaPurple"
    ),
    legend=dict(
    orientation="h",
    yanchor="top",
    y=-0.1,
    xanchor="left",
    x=0.01
)
)

fig2 = go.Figure(data=[go.Table(
    header=dict(values=['ISO-2019 compliant', 'ISO-2019 rejected'],
                line_color='darkslategray',
                fill_color='#FFFFFF',
                align='left'),
    cells=dict(values=[[shorted], # 1st column
                       [excluded]], # 2nd column
               line_color='darkslategray',
               fill_color='#FFFFFF',
               align='left'))
]) 

fig2.update_layout(
    title="Standard compliancy of common core materials",
    height = 500,
    font=dict(
        family="Arial",
        size=10,
        #color="RebeccaPurple"
    ),
)


fig.add_scatter(x=[d_abcd_sigmadccomin2019/kAM,d_abcd_sigmadccomin2019/kAM,4.5,4.5], y=[taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM], fill="toself", name = "EN-ISO-12215:2019 cat.ABCD Displacement motor craft")
fig.add_scatter(x=[0.2,0.2,4.5,4.5], y=[taudcomin2008/kAM,1.0,1.0,taudcomin2008/kAM], fill="toself",name = "EN-ISO-12215:2008 All crafts under 24m")
fig.add_scatter(x=[p_a_sigmadccomin2019/kAM,p_a_sigmadccomin2019/kAM,4.5,4.5], y=[taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM], fill="toself", name = "EN-ISO-12215:2019 cat.A Planning motor craft")
fig.add_scatter(x=[p_b_sigmadccomin2019/kAM,p_b_sigmadccomin2019/kAM,4.5,4.5], y=[taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM], fill="toself", name = "EN-ISO-12215:2019 cat.B Planning motor craft")
fig.add_scatter(x=[p_c_sigmadccomin2019/kAM,p_c_sigmadccomin2019/kAM,4.5,4.5], y=[taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM], fill="toself", name = "EN-ISO-12215:2019 cat.C Planning motor craft")
fig.add_scatter(x=[p_d_sigmadccomin2019/kAM,p_d_sigmadccomin2019/kAM,4.5,4.5], y=[taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM], fill="toself", name = "EN-ISO-12215:2019 cat.D Planning motor craft")
fig.add_scatter(x=[v_abcd_sigmadccomin2019/kAM,v_abcd_sigmadccomin2019/kAM,4.5,4.5], y=[taudcomin2019/kAM,1.0,1.0,taudcomin2019/kAM], fill="toself", name = "EN-ISO-12215:2019 cat.ABCD sailing craft")


display = go.FigureWidget(data = fig, layout = head_display_layout)
display2 = go.FigureWidget(data = fig2)

box_layout = Layout(display='flex',
                    flex_flow='column',
                    align_items='stretch',
                    #border='solid',
                    width='100%')

right_layout = Layout(overflow_x='hidden',
                    overflow_y='auto',
                    display='flex',
                    flex_flow='column',
                    height='800px',
                    align_items='stretch',
                    #border='solid',
                    width='100%')


left_layout = Layout(overflow_x='hidden',
                    overflow_y='auto',
                    display='flex',
                    flex_flow='column',
                    height='800px',
                    #align_items='stretch',
                    #border='solid',
                    width='100%')

lwlButton.observe(update_value, names='value')
mldcButton.observe(update_value, names='value')
#methodeButton.observe(update_value, names='value')
matiereButton.observe(update_value, names='value')
matiereButton.observe(update_TechnicalDocumentation, names='value')
languageButton.observe(update_value, names='value')
languageButton.observe(change_language, names='value')
controlButton.observe(update_control, names='value')
submitterNameButton.observe(update_contract, names='value')

submitterNameButton.observe(check_Submitter, names='value')
submitterAdress.observe(check_Submitter, names='value')
submitterTown.observe(check_Submitter, names='value')
submitterPost.observe(check_Submitter, names='value')
submitterCountry.observe(check_Submitter, names='value')
emailForm.observe(check_Submitter, names='value')
confirmSubmitterButton.on_click(confirm_Submitter)
confirmSubmitterButton.on_click(check_Contract)

modeleButton.observe(check_Product, names='value')
listeDesignCategoryButton.observe(check_Product, names='value')
lwlButton.observe(check_Product, names='value')
mldcButton.observe(check_Product, names='value')
confirmProductButton.on_click(confirm_Product)
confirmProductButton.on_click(check_Contract)

modeleTypeButton.observe(check_Product, names='value')
contextButton.observe(check_Contract)
matiereButton.observe(check_Contract)
controlButton.observe(check_Contract)
uploader.observe(check_Contract)
languageButton.observe(check_Contract)

confirmContractButton.on_click(confirm_Contract)

modeleButton.observe(update_contract, names='value')
contextButton.observe(update_contract, names='value')
modeleButton.observe(update_contract, names='value')
matiereButton.observe(update_contract, names='value')
controlButton.observe(update_contract, names='value')

change_language(True)

#sendemailButton.on_click(sendEmail)

# %%
#copyright section
copyright = widgets.HTML("<font size=1>© A.C.E. CATTELLIOT ENGINEERING 2022</font>")
copyright
# Out:
# HTML(value='<font size=1>© A.C.E. CATTELLIOT ENGINEERING 2022</font>')
